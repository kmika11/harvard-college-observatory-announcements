# %% [markdown]
# # Curation Script - Chinese Maritime Trade Data

# %% [markdown]
# ## About
# - This script contains the basic curation workflow for creating datasets and uploading files from a metadata spreadsheet of data files.
# - **Be SURE `curate.py` and `directupload.py` are set in correct directories**
# <p>
# - **Created:** 2023/10/12
# - **Updated:**

# %% [markdown]
# ## Globals
# - Global variables for this script.
# - Set variable names (e.g., `g_api_key` as needed)

# %%
# set curation source path
g_module_path = '/Users/katherinemika/Desktop/curation/historic_datasets/hco'

# path to output file
g_dataverse_inventory_file = '/Users/katherinemika/Desktop/curation/historic_datasets/hco/hco_batch_metadata.csv'
# series names
g_series_names = []

# dataset inventories (keyed on series name)
g_series_inventories = {}

# dataset metadata (keyed on series name)
g_dataset_metadata = {}

# dataverse installation
g_dataverse_installation_url = 'https://demo.dataverse.org'

# dataverse API key
g_dataverse_api_key = 'e487101b-6f0e-47dc-8109-7a72a9a9b0ed'

# dataverse collection name
g_dataverse_collection = 'hco_card'

# dataverse inventory dataframe
g_dataverse_inventory_df = None

# dataset author
g_dataset_author = 'Mika, Katherine'

# dataset author affiliation
g_dataset_author_affiliation = 'Harvard Library'

# dataset contact information
g_dataset_contact = 'Mika, Katherine'
g_dataset_contact_email = 'katherine_mika@harvard.edu'

# full path to location of datafiles (e.g., ../data/trade_statistics)
g_datafiles_path = '/Users/katherinemika/Desktop/curation/historic_datasets/hco/data_files'
# demo dataverse dataset information (keyed on series name)
g_dataverse_dataset_info = {}

# datafile metadata (dataframe of datafile metadata, keyed on series name)
g_datafile_metadata = {}

# datafile description template
g_datafile_description_template_txt = 'File contains OCR text with data from Announcement Card number:  '
g_datafile_description_template_csv = 'File contains csv table with data from Announcement Card number:  '
g_datafile_description_template_xml = 'File contains xml tree with OCR bounding box data from Annoucement Card: '


# dataset batches (array of batches of series to create/upload)
g_dataset_batches = []

# %% [markdown]
# ## Modules

# %% [markdown]
# - Add local modules path to Jupyter system path
# - Load all modules including local modules such as `curate`

# %%
import sys
if g_module_path not in sys.path:
    sys.path.append(g_module_path)

import curate
import requests
import numpy as np
import pandas as pd
import pprint as pprint
from pyDataverse.api import NativeApi

# %% [markdown]
# ## Local Functions

# %%
# get a dictionary of dataset pids keyed on series name. Collected from output of "create dataset" function
def get_dataset_pids(batch, dataset_info):
    pids = {}
    for series_name in batch:
        pids[series_name] = dataset_info[series_name].get('dataset_pid')
    return pids

def get_dataset_pids_from_hdv(api, dataverse_collection):
    ds_tree = api.get_children(dataverse_collection, children_types=["datasets"])
    key = api.api_token
    base_url = api.base_url
    headers = {'X-Dataverse-key': key}
    
    formatted_ds_tree = {}
    
    for t in ds_tree:
        pid = t['pid']
        request_url = '{}/api/datasets/:persistentId/?persistentId={}'.format(base_url, pid)
        response = requests.get(request_url, headers=headers)
        if response.status_code == 200:
            r = response.json()
            title = r['data']['latestVersion']['metadataBlocks']['citation']['fields'][0]['value']
            dataset_id = r['data']['id']
            formatted_ds_tree[title] = {
                'dataset_id': dataset_id,
                'dataset_pid': pid,
                'status': True
            }
        else:
            print(f"Failed to retrieve data for PID: {pid}")
    
    return formatted_ds_tree

# get dictionary of datafile inventories keyed on series name
def get_datafile_inventories(batch, datafile_metadata):
    inventories = {}
    for series_name in batch:
        inventories[series_name] = datafile_metadata[series_name]
    return inventories 

# upload the datafiles associated with a batch
def upload_dataset_batch(api, dataverse_url, batch_list, batch_pids, batch_datafile_metadata, data_directory):
    # upload the datafiles associated with each series in the batch
    results = {}
    for series_name in batch_list:
        pid = batch_pids[series_name]
        datafiles_metadata = batch_datafile_metadata[series_name]
        results[series_name] = curate.direct_upload_datafiles(api, dataverse_url, pid, path, datafiles_metadata)
    return results

# upload datafiles for a batch of datasets
def upload_files_batch(api, dataverse_url, batch_list, batch_pids, data_directory, batch_datafile_metadata):
    results = {}
    for series_name in batch_list:
        pid = batch_pids[series_name]
        batch_datafile_metadata = g_datafile_metadata[series_name]
        results[series_name] = curate.python_dvuploader(api, dataverse_url, pid, data_directory, batch_datafile_metadata)
    return results

# upload datafiles for a batch of datasets - but ignoring 500 errors that the python_dvuploader keeps issuing...
def upload_files_batch_errors(api, dataverse_url, batch_list, batch_pids, data_directory, g_datafile_metadata):
    results = {}
    for series_name in batch_list:
        try:
            pid = batch_pids[series_name]
            batch_datafile_metadata = g_datafile_metadata[series_name]
            results[series_name] = curate.python_dvuploader(api, dataverse_url, pid, data_directory, batch_datafile_metadata)
        except Exception as e:
            if "500" in str(e):
                print(f"500 error encountered for {series_name}. Skipping to the next series.")
                continue
            else:
                # Handle other exceptions if necessary
                raise e
    return results

# %% [markdown]
# ## Curate Inventory

# %% [markdown]
# ### 1. Prepare inventory data for curation

# %% [markdown]
# #### 1.1 Read `dataverse_inventory`
# - **Add instructions about spreadsheet format** Eg. Column names, table org, etc.
# - Create a `DataFrame` for later use
# - Note: Also, the `curate:direct_upload_datafiles` function expects all files to be in a single directory (not grouped by file type)

# %%
# read the dataverse inventory file
import chardet

with open(g_dataverse_inventory_file, 'rb') as f: 
    result = chardet.detect(f.read())
    encoding = result['encoding']
    print(f"detected encoding: {encoding}")
    
g_dataverse_inventory_df = pd.read_csv(g_dataverse_inventory_file,index_col=None, encoding=encoding, low_memory=False)
# Out:
# detected encoding: UTF-8-SIG

# %%
g_dataverse_inventory_df
# Out:
#                                    filename file_type  card_number  \
# 0     HCOAnnouncement0001_0001.innodata.xml       xml            1
# 1     HCOAnnouncement0001_0001.innodata.jpg       jpg            1
# 2     HCOAnnouncement0001_0001.innodata.txt       txt            1
# 3   HCOAnnouncement0001_0001_a.innodata.csv       csv            1
# 4   HCOAnnouncement0001_0001_b.innodata.csv       csv            1
# 5     HCOAnnouncement0001_0002.innodata.xml       xml            2
# 6     HCOAnnouncement0001_0002.innodata.jpg       jpg            2
# 7     HCOAnnouncement0001_0002.innodata.txt       txt            2
# 8   HCOAnnouncement0001_0002_a.innodata.csv       csv            2
# 9   HCOAnnouncement0001_0002_b.innodata.csv       csv            2
# 10  HCOAnnouncement0001_0002_c.innodata.csv       csv            2
# 11    HCOAnnouncement0001_0003.innodata.xml       xml            3
# 12    HCOAnnouncement0001_0003.innodata.jpg       jpg            3
# 13    HCOAnnouncement0001_0003.innodata.txt       txt            3
# 14    HCOAnnouncement0001_0004.innodata.xml       xml            4
# 15    HCOAnnouncement0001_0004.innodata.jpg       jpg            4
# 16    HCOAnnouncement0001_0004.innodata.txt       txt            4
# 17  HCOAnnouncement0001_0004_a.innodata.csv       csv            4
# 18    HCOAnnouncement0001_0005.innodata.xml       xml            5
# 19    HCOAnnouncement0001_0005.innodata.jpg       jpg            5
# 20    HCOAnnouncement0001_0005.innodata.txt       txt            5
# 21  HCOAnnouncement0001_0005_a.innodata.csv       csv            5
# 22    HCOAnnouncement0001_0006.innodata.xml       xml            6
# 23    HCOAnnouncement0001_0006.innodata.jpg       jpg            6
# 24    HCOAnnouncement0001_0006.innodata.txt       txt            6
# 25  HCOAnnouncement0001_0006_a.innodata.csv       csv            6
# 26    HCOAnnouncement0001_0007.innodata.xml       xml            7
# 27    HCOAnnouncement0001_0007.innodata.jpg       jpg            7
# 28    HCOAnnouncement0001_0007.innodata.txt       txt            7
# 29  HCOAnnouncement0001_0007_a.innodata.csv       csv            7
# 30    HCOAnnouncement0001_0008.innodata.xml       xml            8
# 31    HCOAnnouncement0001_0008.innodata.jpg       jpg            8
# 32    HCOAnnouncement0001_0008.innodata.txt       txt            8
# 33  HCOAnnouncement0001_0008_a.innodata.csv       csv            8
# 34  HCOAnnouncement0001_0008_b.innodata.csv       csv            8
# 35  HCOAnnouncement0001_0008_c.innodata.csv       csv            8
# 36    HCOAnnouncement0001_0009.innodata.xml       xml            9
# 37    HCOAnnouncement0001_0009.innodata.jpg       jpg            9
# 38    HCOAnnouncement0001_0009.innodata.txt       txt            9
# 39  HCOAnnouncement0001_0009_a.innodata.csv       csv            9
# 40    HCOAnnouncement0001_0010.innodata.xml       xml           10
# 41    HCOAnnouncement0001_0010.innodata.jpg       jpg           10
# 42    HCOAnnouncement0001_0010.innodata.txt       txt           10
# 43  HCOAnnouncement0001_0010_a.innodata.csv       csv           10
# 44    HCOAnnouncement0001_0011.innodata.xml       xml           11
# 45    HCOAnnouncement0001_0011.innodata.jpg       jpg           11
# 46    HCOAnnouncement0001_0011.innodata.txt       txt           11
# 47  HCOAnnouncement0001_0011_a.innodata.csv       csv           11
# 48    HCOAnnouncement0001_0012.innodata.xml       xml           12
# 49    HCOAnnouncement0001_0012.innodata.jpg       jpg           12
# 50    HCOAnnouncement0001_0012.innodata.txt       txt           12
# 51  HCOAnnouncement0001_0012_a.innodata.csv       csv           12
# 52  HCOAnnouncement0001_0012_b.innodata.csv       csv           12
# 53  HCOAnnouncement0001_0012_c.innodata.csv       csv           12
# 54    HCOAnnouncement0001_0013.innodata.xml       xml           13
# 55    HCOAnnouncement0001_0013.innodata.jpg       jpg           13
# 56    HCOAnnouncement0001_0013.innodata.txt       txt           13
# 57  HCOAnnouncement0001_0013_a.innodata.csv       csv           13
# 58  HCOAnnouncement0001_0013_b.innodata.csv       csv           13
# 59  HCOAnnouncement0001_0013_c.innodata.csv       csv           13
#
#     card_date_year  card_date_month  card_date_day     contributor  \
# 0             1926                3             12  Harlow Shapley
# 1             1926                3             12  Harlow Shapley
# 2             1926                3             12  Harlow Shapley
# 3             1926                3             12  Harlow Shapley
# 4             1926                3             12  Harlow Shapley
# 5             1926                3             18  Harlow Shapley
# 6             1926                3             18  Harlow Shapley
# 7             1926                3             18  Harlow Shapley
# 8             1926                3             18  Harlow Shapley
# 9             1926                3             18  Harlow Shapley
# 10            1926                3             18  Harlow Shapley
# 11            1926                5             15  Harlow Shapley
# 12            1926                5             15  Harlow Shapley
# 13            1926                5             15  Harlow Shapley
# 14            1926                7             15  Harlow Shapley
# 15            1926                7             15  Harlow Shapley
# 16            1926                7             15  Harlow Shapley
# 17            1926                7             15  Harlow Shapley
# 18            1926                8              4  Harlow Shapley
# 19            1926                8              4  Harlow Shapley
# 20            1926                8              4  Harlow Shapley
# 21            1926                8              4  Harlow Shapley
# 22            1926                9              3  Harlow Shapley
# 23            1926                9              3  Harlow Shapley
# 24            1926                9              3  Harlow Shapley
# 25            1926                9              3  Harlow Shapley
# 26            1926               10             18  Harlow Shapley
# 27            1926               10             18  Harlow Shapley
# 28            1926               10             18  Harlow Shapley
# 29            1926               10             18  Harlow Shapley
# 30            1926               11              8  Harlow Shapley
# 31            1926               11              8  Harlow Shapley
# 32            1926               11              8  Harlow Shapley
# 33            1926               11              8  Harlow Shapley
# 34            1926               11              8  Harlow Shapley
# 35            1926               11              8  Harlow Shapley
# 36            1920               11             10  Harlow Shapley
# 37            1920               11             10  Harlow Shapley
# 38            1920               11             10  Harlow Shapley
# 39            1920               11             10  Harlow Shapley
# 40            1926               11             11  Harlow Shapley
# 41            1926               11             11  Harlow Shapley
# 42            1926               11             11  Harlow Shapley
# 43            1926               11             11  Harlow Shapley
# 44            1926               11             12  Harlow Shapley
# 45            1926               11             12  Harlow Shapley
# 46            1926               11             12  Harlow Shapley
# 47            1926               11             12  Harlow Shapley
# 48            1926               11             15  Harlow Shapley
# 49            1926               11             15  Harlow Shapley
# 50            1926               11             15  Harlow Shapley
# 51            1926               11             15  Harlow Shapley
# 52            1926               11             15  Harlow Shapley
# 53            1926               11             15  Harlow Shapley
# 54            1926               12             15  Harlow Shapley
# 55            1926               12             15  Harlow Shapley
# 56            1926               12             15  Harlow Shapley
# 57            1926               12             15  Harlow Shapley
# 58            1926               12             15  Harlow Shapley
# 59            1926               12             15  Harlow Shapley
#
#                                   observation  \
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# 3                         BLATHWAYT’S COMET
# 4                         BLATHWAYT’S COMET
# 5                                         NaN
# 6                                         NaN
# 7                                         NaN
# 8                               ENSOR'S COMET
# 9                               ENSOR'S COMET
# 10                        BLATHWAYT’S COMET
# 11                                        NaN
# 12                                        NaN
# 13                                        NaN
# 14                                        NaN
# 15                                        NaN
# 16                                        NaN
# 17                    KOPFF'S COMET (1906-IV)
# 18                                        NaN
# 19                                        NaN
# 20                                        NaN
# 21                  FINLAY'S COMET (1886 VII)
# 22                                        NaN
# 23                                        NaN
# 24                                        NaN
# 25                       WILK COMETARY OBJECT
# 26                                        NaN
# 27                                        NaN
# 28                                        NaN
# 29  GIACOBINI-ZINNER COMET (1900 III, 1913 e)
# 30                                        NaN
# 31                                        NaN
# 32                                        NaN
# 33                                  New Comet
# 34                                  New Comet
# 35                            NEUJMIN'S COMET
# 36                                        NaN
# 37                                        NaN
# 38                                        NaN
# 39                         COMAS SOLA'S COMET
# 40                                        NaN
# 41                                        NaN
# 42                                        NaN
# 43                         COMAS SOLA'S COMET
# 44                                        NaN
# 45                                        NaN
# 46                                        NaN
# 47               ORBIT OF COMAS SOLA'S CCOMET
# 48                                        NaN
# 49                                        NaN
# 50                                        NaN
# 51                         COMAS SOLA'S COMET
# 52                         COMAS SOLA'S COMET
# 53                         COMAS SOLA'S COMET
# 54                                        NaN
# 55                                        NaN
# 56                                        NaN
# 57                COMAS SOLA'S COMET (1926 f)
# 58                COMAS SOLA'S COMET (1926 f)
# 59                COMAS SOLA'S COMET (1926 f)
#
#                              all_observations                   series_name  \
# 0                           BLATHWAYT'S COMET   Announcement Card number: 1
# 1                           BLATHWAYT'S COMET   Announcement Card number: 1
# 2                           BLATHWAYT'S COMET   Announcement Card number: 1
# 3                           BLATHWAYT'S COMET   Announcement Card number: 1
# 4                           BLATHWAYT'S COMET   Announcement Card number: 1
# 5            ENSOR'S COMET; BLATHWAYT'S COMET   Announcement Card number: 2
# 6            ENSOR'S COMET; BLATHWAYT'S COMET   Announcement Card number: 2
# 7            ENSOR'S COMET; BLATHWAYT'S COMET   Announcement Card number: 2
# 8            ENSOR'S COMET; BLATHWAYT'S COMET   Announcement Card number: 2
# 9            ENSOR'S COMET; BLATHWAYT'S COMET   Announcement Card number: 2
# 10           ENSOR'S COMET; BLATHWAYT'S COMET   Announcement Card number: 2
# 11                                        NaN   Announcement Card number: 3
# 12                                        NaN   Announcement Card number: 3
# 13                                        NaN   Announcement Card number: 3
# 14                    KOPFF'S COMET (1906-IV)   Announcement Card number: 4
# 15                    KOPFF'S COMET (1906-IV)   Announcement Card number: 4
# 16                    KOPFF'S COMET (1906-IV)   Announcement Card number: 4
# 17                    KOPFF'S COMET (1906-IV)   Announcement Card number: 4
# 18                  FINLAY'S COMET (1886 VII)   Announcement Card number: 5
# 19                  FINLAY'S COMET (1886 VII)   Announcement Card number: 5
# 20                  FINLAY'S COMET (1886 VII)   Announcement Card number: 5
# 21                  FINLAY'S COMET (1886 VII)   Announcement Card number: 5
# 22                       WILK COMETARY OBJECT   Announcement Card number: 6
# 23                       WILK COMETARY OBJECT   Announcement Card number: 6
# 24                       WILK COMETARY OBJECT   Announcement Card number: 6
# 25                       WILK COMETARY OBJECT   Announcement Card number: 6
# 26  GIACOBINI-ZINNER COMET (1900 III, 1913 e)   Announcement Card number: 7
# 27  GIACOBINI-ZINNER COMET (1900 III, 1913 e)   Announcement Card number: 7
# 28  GIACOBINI-ZINNER COMET (1900 III, 1913 e)   Announcement Card number: 7
# 29  GIACOBINI-ZINNER COMET (1900 III, 1913 e)   Announcement Card number: 7
# 30                 New Comet; NEUJMIN'S COMET   Announcement Card number: 8
# 31                 New Comet; NEUJMIN'S COMET   Announcement Card number: 8
# 32                 New Comet; NEUJMIN'S COMET   Announcement Card number: 8
# 33                 New Comet; NEUJMIN'S COMET   Announcement Card number: 8
# 34                 New Comet; NEUJMIN'S COMET   Announcement Card number: 8
# 35                 New Comet; NEUJMIN'S COMET   Announcement Card number: 8
# 36                         COMAS SOLA'S COMET   Announcement Card number: 9
# 37                         COMAS SOLA'S COMET   Announcement Card number: 9
# 38                         COMAS SOLA'S COMET   Announcement Card number: 9
# 39                         COMAS SOLA'S COMET   Announcement Card number: 9
# 40                         COMAS SOLA'S COMET  Announcement Card number: 10
# 41                         COMAS SOLA'S COMET  Announcement Card number: 10
# 42                         COMAS SOLA'S COMET  Announcement Card number: 10
# 43                         COMAS SOLA'S COMET  Announcement Card number: 10
# 44               ORBIT OF COMAS SOLA'S CCOMET  Announcement Card number: 11
# 45               ORBIT OF COMAS SOLA'S CCOMET  Announcement Card number: 11
# 46               ORBIT OF COMAS SOLA'S CCOMET  Announcement Card number: 11
# 47               ORBIT OF COMAS SOLA'S CCOMET  Announcement Card number: 11
# 48                         COMAS SOLA'S COMET  Announcement Card number: 12
# 49                         COMAS SOLA'S COMET  Announcement Card number: 12
# 50                         COMAS SOLA'S COMET  Announcement Card number: 12
# 51                         COMAS SOLA'S COMET  Announcement Card number: 12
# 52                         COMAS SOLA'S COMET  Announcement Card number: 12
# 53                         COMAS SOLA'S COMET  Announcement Card number: 12
# 54                COMAS SOLA'S COMET (1926 f)  Announcement Card number: 13
# 55                COMAS SOLA'S COMET (1926 f)  Announcement Card number: 13
# 56                COMAS SOLA'S COMET (1926 f)  Announcement Card number: 13
# 57                COMAS SOLA'S COMET (1926 f)  Announcement Card number: 13
# 58                COMAS SOLA'S COMET (1926 f)  Announcement Card number: 13
# 59                COMAS SOLA'S COMET (1926 f)  Announcement Card number: 13
#
#                                                  url  \
# 0   http://tamkin2.eps.harvard.edu/IAUCs/HAC0001.jpg
# 1   http://tamkin2.eps.harvard.edu/IAUCs/HAC0001.jpg
# 2   http://tamkin2.eps.harvard.edu/IAUCs/HAC0001.jpg
# 3   http://tamkin2.eps.harvard.edu/IAUCs/HAC0001.jpg
# 4   http://tamkin2.eps.harvard.edu/IAUCs/HAC0001.jpg
# 5   http://tamkin2.eps.harvard.edu/IAUCs/HAC0002.jpg
# 6   http://tamkin2.eps.harvard.edu/IAUCs/HAC0002.jpg
# 7   http://tamkin2.eps.harvard.edu/IAUCs/HAC0002.jpg
# 8   http://tamkin2.eps.harvard.edu/IAUCs/HAC0002.jpg
# 9   http://tamkin2.eps.harvard.edu/IAUCs/HAC0002.jpg
# 10  http://tamkin2.eps.harvard.edu/IAUCs/HAC0002.jpg
# 11                                               NaN
# 12                                               NaN
# 13                                               NaN
# 14                                               NaN
# 15                                               NaN
# 16                                               NaN
# 17                                               NaN
# 18                                               NaN
# 19                                               NaN
# 20                                               NaN
# 21                                               NaN
# 22                                               NaN
# 23                                               NaN
# 24                                               NaN
# 25                                               NaN
# 26                                               NaN
# 27                                               NaN
# 28                                               NaN
# 29                                               NaN
# 30                                               NaN
# 31                                               NaN
# 32                                               NaN
# 33                                               NaN
# 34                                               NaN
# 35                                               NaN
# 36                                               NaN
# 37                                               NaN
# 38                                               NaN
# 39                                               NaN
# 40                                               NaN
# 41                                               NaN
# 42                                               NaN
# 43                                               NaN
# 44                                               NaN
# 45                                               NaN
# 46                                               NaN
# 47                                               NaN
# 48                                               NaN
# 49                                               NaN
# 50                                               NaN
# 51                                               NaN
# 52                                               NaN
# 53                                               NaN
# 54                                               NaN
# 55                                               NaN
# 56                                               NaN
# 57                                               NaN
# 58                                               NaN
# 59                                               NaN
#
#                                       volume_title  \
# 0   Harvard College Observatory Announcement Cards
# 1   Harvard College Observatory Announcement Cards
# 2   Harvard College Observatory Announcement Cards
# 3   Harvard College Observatory Announcement Cards
# 4   Harvard College Observatory Announcement Cards
# 5   Harvard College Observatory Announcement Cards
# 6   Harvard College Observatory Announcement Cards
# 7   Harvard College Observatory Announcement Cards
# 8   Harvard College Observatory Announcement Cards
# 9   Harvard College Observatory Announcement Cards
# 10  Harvard College Observatory Announcement Cards
# 11  Harvard College Observatory Announcement Cards
# 12  Harvard College Observatory Announcement Cards
# 13  Harvard College Observatory Announcement Cards
# 14  Harvard College Observatory Announcement Cards
# 15  Harvard College Observatory Announcement Cards
# 16  Harvard College Observatory Announcement Cards
# 17  Harvard College Observatory Announcement Cards
# 18  Harvard College Observatory Announcement Cards
# 19  Harvard College Observatory Announcement Cards
# 20  Harvard College Observatory Announcement Cards
# 21  Harvard College Observatory Announcement Cards
# 22  Harvard College Observatory Announcement Cards
# 23  Harvard College Observatory Announcement Cards
# 24  Harvard College Observatory Announcement Cards
# 25  Harvard College Observatory Announcement Cards
# 26  Harvard College Observatory Announcement Cards
# 27  Harvard College Observatory Announcement Cards
# 28  Harvard College Observatory Announcement Cards
# 29  Harvard College Observatory Announcement Cards
# 30  Harvard College Observatory Announcement Cards
# 31  Harvard College Observatory Announcement Cards
# 32  Harvard College Observatory Announcement Cards
# 33  Harvard College Observatory Announcement Cards
# 34  Harvard College Observatory Announcement Cards
# 35  Harvard College Observatory Announcement Cards
# 36  Harvard College Observatory Announcement Cards
# 37  Harvard College Observatory Announcement Cards
# 38  Harvard College Observatory Announcement Cards
# 39  Harvard College Observatory Announcement Cards
# 40  Harvard College Observatory Announcement Cards
# 41  Harvard College Observatory Announcement Cards
# 42  Harvard College Observatory Announcement Cards
# 43  Harvard College Observatory Announcement Cards
# 44  Harvard College Observatory Announcement Cards
# 45  Harvard College Observatory Announcement Cards
# 46  Harvard College Observatory Announcement Cards
# 47  Harvard College Observatory Announcement Cards
# 48  Harvard College Observatory Announcement Cards
# 49  Harvard College Observatory Announcement Cards
# 50  Harvard College Observatory Announcement Cards
# 51  Harvard College Observatory Announcement Cards
# 52  Harvard College Observatory Announcement Cards
# 53  Harvard College Observatory Announcement Cards
# 54  Harvard College Observatory Announcement Cards
# 55  Harvard College Observatory Announcement Cards
# 56  Harvard College Observatory Announcement Cards
# 57  Harvard College Observatory Announcement Cards
# 58  Harvard College Observatory Announcement Cards
# 59  Harvard College Observatory Announcement Cards
#
#                       published  \
# 0   Harvard College Observatory
# 1   Harvard College Observatory
# 2   Harvard College Observatory
# 3   Harvard College Observatory
# 4   Harvard College Observatory
# 5   Harvard College Observatory
# 6   Harvard College Observatory
# 7   Harvard College Observatory
# 8   Harvard College Observatory
# 9   Harvard College Observatory
# 10  Harvard College Observatory
# 11  Harvard College Observatory
# 12  Harvard College Observatory
# 13  Harvard College Observatory
# 14  Harvard College Observatory
# 15  Harvard College Observatory
# 16  Harvard College Observatory
# 17  Harvard College Observatory
# 18  Harvard College Observatory
# 19  Harvard College Observatory
# 20  Harvard College Observatory
# 21  Harvard College Observatory
# 22  Harvard College Observatory
# 23  Harvard College Observatory
# 24  Harvard College Observatory
# 25  Harvard College Observatory
# 26  Harvard College Observatory
# 27  Harvard College Observatory
# 28  Harvard College Observatory
# 29  Harvard College Observatory
# 30  Harvard College Observatory
# 31  Harvard College Observatory
# 32  Harvard College Observatory
# 33  Harvard College Observatory
# 34  Harvard College Observatory
# 35  Harvard College Observatory
# 36  Harvard College Observatory
# 37  Harvard College Observatory
# 38  Harvard College Observatory
# 39  Harvard College Observatory
# 40  Harvard College Observatory
# 41  Harvard College Observatory
# 42  Harvard College Observatory
# 43  Harvard College Observatory
# 44  Harvard College Observatory
# 45  Harvard College Observatory
# 46  Harvard College Observatory
# 47  Harvard College Observatory
# 48  Harvard College Observatory
# 49  Harvard College Observatory
# 50  Harvard College Observatory
# 51  Harvard College Observatory
# 52  Harvard College Observatory
# 53  Harvard College Observatory
# 54  Harvard College Observatory
# 55  Harvard College Observatory
# 56  Harvard College Observatory
# 57  Harvard College Observatory
# 58  Harvard College Observatory
# 59  Harvard College Observatory
#
#                                              subjects  \
# 0   Astronomy--Observations; Astronomy--Research; ...
# 1   Astronomy--Observations; Astronomy--Research; ...
# 2   Astronomy--Observations; Astronomy--Research; ...
# 3   Astronomy--Observations; Astronomy--Research; ...
# 4   Astronomy--Observations; Astronomy--Research; ...
# 5   Astronomy--Observations; Astronomy--Research; ...
# 6   Astronomy--Observations; Astronomy--Research; ...
# 7   Astronomy--Observations; Astronomy--Research; ...
# 8   Astronomy--Observations; Astronomy--Research; ...
# 9   Astronomy--Observations; Astronomy--Research; ...
# 10  Astronomy--Observations; Astronomy--Research; ...
# 11  Astronomy--Observations; Astronomy--Research; ...
# 12  Astronomy--Observations; Astronomy--Research; ...
# 13  Astronomy--Observations; Astronomy--Research; ...
# 14  Astronomy--Observations; Astronomy--Research; ...
# 15  Astronomy--Observations; Astronomy--Research; ...
# 16  Astronomy--Observations; Astronomy--Research; ...
# 17  Astronomy--Observations; Astronomy--Research; ...
# 18  Astronomy--Observations; Astronomy--Research; ...
# 19  Astronomy--Observations; Astronomy--Research; ...
# 20  Astronomy--Observations; Astronomy--Research; ...
# 21  Astronomy--Observations; Astronomy--Research; ...
# 22  Astronomy--Observations; Astronomy--Research; ...
# 23  Astronomy--Observations; Astronomy--Research; ...
# 24  Astronomy--Observations; Astronomy--Research; ...
# 25  Astronomy--Observations; Astronomy--Research; ...
# 26  Astronomy--Observations; Astronomy--Research; ...
# 27  Astronomy--Observations; Astronomy--Research; ...
# 28  Astronomy--Observations; Astronomy--Research; ...
# 29  Astronomy--Observations; Astronomy--Research; ...
# 30  Astronomy--Observations; Astronomy--Research; ...
# 31  Astronomy--Observations; Astronomy--Research; ...
# 32  Astronomy--Observations; Astronomy--Research; ...
# 33  Astronomy--Observations; Astronomy--Research; ...
# 34  Astronomy--Observations; Astronomy--Research; ...
# 35  Astronomy--Observations; Astronomy--Research; ...
# 36  Astronomy--Observations; Astronomy--Research; ...
# 37  Astronomy--Observations; Astronomy--Research; ...
# 38  Astronomy--Observations; Astronomy--Research; ...
# 39  Astronomy--Observations; Astronomy--Research; ...
# 40  Astronomy--Observations; Astronomy--Research; ...
# 41  Astronomy--Observations; Astronomy--Research; ...
# 42  Astronomy--Observations; Astronomy--Research; ...
# 43  Astronomy--Observations; Astronomy--Research; ...
# 44  Astronomy--Observations; Astronomy--Research; ...
# 45  Astronomy--Observations; Astronomy--Research; ...
# 46  Astronomy--Observations; Astronomy--Research; ...
# 47  Astronomy--Observations; Astronomy--Research; ...
# 48  Astronomy--Observations; Astronomy--Research; ...
# 49  Astronomy--Observations; Astronomy--Research; ...
# 50  Astronomy--Observations; Astronomy--Research; ...
# 51  Astronomy--Observations; Astronomy--Research; ...
# 52  Astronomy--Observations; Astronomy--Research; ...
# 53  Astronomy--Observations; Astronomy--Research; ...
# 54  Astronomy--Observations; Astronomy--Research; ...
# 55  Astronomy--Observations; Astronomy--Research; ...
# 56  Astronomy--Observations; Astronomy--Research; ...
# 57  Astronomy--Observations; Astronomy--Research; ...
# 58  Astronomy--Observations; Astronomy--Research; ...
# 59  Astronomy--Observations; Astronomy--Research; ...
#
#                                  topic_class  \
# 0   History of Science; History of Astronomy
# 1   History of Science; History of Astronomy
# 2   History of Science; History of Astronomy
# 3   History of Science; History of Astronomy
# 4   History of Science; History of Astronomy
# 5   History of Science; History of Astronomy
# 6   History of Science; History of Astronomy
# 7   History of Science; History of Astronomy
# 8   History of Science; History of Astronomy
# 9   History of Science; History of Astronomy
# 10  History of Science; History of Astronomy
# 11  History of Science; History of Astronomy
# 12  History of Science; History of Astronomy
# 13  History of Science; History of Astronomy
# 14  History of Science; History of Astronomy
# 15  History of Science; History of Astronomy
# 16  History of Science; History of Astronomy
# 17  History of Science; History of Astronomy
# 18  History of Science; History of Astronomy
# 19  History of Science; History of Astronomy
# 20  History of Science; History of Astronomy
# 21  History of Science; History of Astronomy
# 22  History of Science; History of Astronomy
# 23  History of Science; History of Astronomy
# 24  History of Science; History of Astronomy
# 25  History of Science; History of Astronomy
# 26  History of Science; History of Astronomy
# 27  History of Science; History of Astronomy
# 28  History of Science; History of Astronomy
# 29  History of Science; History of Astronomy
# 30  History of Science; History of Astronomy
# 31  History of Science; History of Astronomy
# 32  History of Science; History of Astronomy
# 33  History of Science; History of Astronomy
# 34  History of Science; History of Astronomy
# 35  History of Science; History of Astronomy
# 36  History of Science; History of Astronomy
# 37  History of Science; History of Astronomy
# 38  History of Science; History of Astronomy
# 39  History of Science; History of Astronomy
# 40  History of Science; History of Astronomy
# 41  History of Science; History of Astronomy
# 42  History of Science; History of Astronomy
# 43  History of Science; History of Astronomy
# 44  History of Science; History of Astronomy
# 45  History of Science; History of Astronomy
# 46  History of Science; History of Astronomy
# 47  History of Science; History of Astronomy
# 48  History of Science; History of Astronomy
# 49  History of Science; History of Astronomy
# 50  History of Science; History of Astronomy
# 51  History of Science; History of Astronomy
# 52  History of Science; History of Astronomy
# 53  History of Science; History of Astronomy
# 54  History of Science; History of Astronomy
# 55  History of Science; History of Astronomy
# 56  History of Science; History of Astronomy
# 57  History of Science; History of Astronomy
# 58  History of Science; History of Astronomy
# 59  History of Science; History of Astronomy
#
#                                             permalink
# 0   http://tamkin2.eps.harvard.edu/services/HACs.html
# 1   http://tamkin2.eps.harvard.edu/services/HACs.html
# 2   http://tamkin2.eps.harvard.edu/services/HACs.html
# 3   http://tamkin2.eps.harvard.edu/services/HACs.html
# 4   http://tamkin2.eps.harvard.edu/services/HACs.html
# 5   http://tamkin2.eps.harvard.edu/services/HACs.html
# 6   http://tamkin2.eps.harvard.edu/services/HACs.html
# 7   http://tamkin2.eps.harvard.edu/services/HACs.html
# 8   http://tamkin2.eps.harvard.edu/services/HACs.html
# 9   http://tamkin2.eps.harvard.edu/services/HACs.html
# 10  http://tamkin2.eps.harvard.edu/services/HACs.html
# 11  http://tamkin2.eps.harvard.edu/services/HACs.html
# 12  http://tamkin2.eps.harvard.edu/services/HACs.html
# 13  http://tamkin2.eps.harvard.edu/services/HACs.html
# 14  http://tamkin2.eps.harvard.edu/services/HACs.html
# 15  http://tamkin2.eps.harvard.edu/services/HACs.html
# 16  http://tamkin2.eps.harvard.edu/services/HACs.html
# 17  http://tamkin2.eps.harvard.edu/services/HACs.html
# 18  http://tamkin2.eps.harvard.edu/services/HACs.html
# 19  http://tamkin2.eps.harvard.edu/services/HACs.html
# 20  http://tamkin2.eps.harvard.edu/services/HACs.html
# 21  http://tamkin2.eps.harvard.edu/services/HACs.html
# 22  http://tamkin2.eps.harvard.edu/services/HACs.html
# 23  http://tamkin2.eps.harvard.edu/services/HACs.html
# 24  http://tamkin2.eps.harvard.edu/services/HACs.html
# 25  http://tamkin2.eps.harvard.edu/services/HACs.html
# 26  http://tamkin2.eps.harvard.edu/services/HACs.html
# 27  http://tamkin2.eps.harvard.edu/services/HACs.html
# 28  http://tamkin2.eps.harvard.edu/services/HACs.html
# 29  http://tamkin2.eps.harvard.edu/services/HACs.html
# 30  http://tamkin2.eps.harvard.edu/services/HACs.html
# 31  http://tamkin2.eps.harvard.edu/services/HACs.html
# 32  http://tamkin2.eps.harvard.edu/services/HACs.html
# 33  http://tamkin2.eps.harvard.edu/services/HACs.html
# 34  http://tamkin2.eps.harvard.edu/services/HACs.html
# 35  http://tamkin2.eps.harvard.edu/services/HACs.html
# 36  http://tamkin2.eps.harvard.edu/services/HACs.html
# 37  http://tamkin2.eps.harvard.edu/services/HACs.html
# 38  http://tamkin2.eps.harvard.edu/services/HACs.html
# 39  http://tamkin2.eps.harvard.edu/services/HACs.html
# 40  http://tamkin2.eps.harvard.edu/services/HACs.html
# 41  http://tamkin2.eps.harvard.edu/services/HACs.html
# 42  http://tamkin2.eps.harvard.edu/services/HACs.html
# 43  http://tamkin2.eps.harvard.edu/services/HACs.html
# 44  http://tamkin2.eps.harvard.edu/services/HACs.html
# 45  http://tamkin2.eps.harvard.edu/services/HACs.html
# 46  http://tamkin2.eps.harvard.edu/services/HACs.html
# 47  http://tamkin2.eps.harvard.edu/services/HACs.html
# 48  http://tamkin2.eps.harvard.edu/services/HACs.html
# 49  http://tamkin2.eps.harvard.edu/services/HACs.html
# 50  http://tamkin2.eps.harvard.edu/services/HACs.html
# 51  http://tamkin2.eps.harvard.edu/services/HACs.html
# 52  http://tamkin2.eps.harvard.edu/services/HACs.html
# 53  http://tamkin2.eps.harvard.edu/services/HACs.html
# 54  http://tamkin2.eps.harvard.edu/services/HACs.html
# 55  http://tamkin2.eps.harvard.edu/services/HACs.html
# 56  http://tamkin2.eps.harvard.edu/services/HACs.html
# 57  http://tamkin2.eps.harvard.edu/services/HACs.html
# 58  http://tamkin2.eps.harvard.edu/services/HACs.html
# 59  http://tamkin2.eps.harvard.edu/services/HACs.html

# %% [markdown]
# #### 1.2 Create Dataset Inventories
# - Get the list of series names
# - Create a `dict` of file inventories keyed on series name

# %%
# get list of series in the full inventory
g_series_names = list(g_dataverse_inventory_df.series_name.unique())

# create series inventories
for name in g_series_names:
    # get series inventory
    g_series_inventories[name] = g_dataverse_inventory_df.loc[g_dataverse_inventory_df['series_name'] == name]

pprint.pprint(g_series_names)
# Out:
# ['Announcement Card number: 1',
#  'Announcement Card number: 2',
#  'Announcement Card number: 3',
#  'Announcement Card number: 4',
#  'Announcement Card number: 5',
#  'Announcement Card number: 6',
#  'Announcement Card number: 7',
#  'Announcement Card number: 8',
#  'Announcement Card number: 9',
#  'Announcement Card number: 10',
#  'Announcement Card number: 11',
#  'Announcement Card number: 12',
#  'Announcement Card number: 13']

# %% [markdown]
# #### 1.3 Create Dataset Metadata
# - Create a `dict` of dataset metadata extracted from each inventory

# %%
# for each series name, create dataset metadata
for series_name in g_series_names:
    # get series inventory
    series_inventory = g_series_inventories[series_name]
    md = curate.create_dataset_metadata(g_dataset_author, g_dataset_author_affiliation, 
                                        g_dataset_contact, g_dataset_contact_email,
                                        series_name, series_inventory)
    g_dataset_metadata[series_name] = md

pprint.pprint(g_dataset_metadata)
# Out:
# {'Announcement Card number: 1': {'astroFacility': ['Harvard Bureau of '
#                                                    'Astronomical Telegrams'],
#                                  'astroObject': [{'objectValue': "BLATHWAYT'S "
#                                                                  'COMET'}],
#                                  'author': [{'authorAffiliation': 'Harvard '
#                                                                   'Library',
#                                              'authorName': 'Mika, Katherine'}],
#                                  'contact': [{'datasetContactAffiliation': 'Harvard '
#                                                                            'Library',
#                                               'datasetContactEmail': 'katherine_mika@harvard.edu',
#                                               'datasetContactName': 'Mika, '
#                                                                     'Katherine'}],
#                                  'creation_date': '1926-3-12',
#                                  'data_source': ['http://tamkin2.eps.harvard.edu/IAUCs/HAC0001.jpg'],
#                                  'description': [{'dsDescriptionValue': 'Announcement '
#                                                                         'Card '
#                                                                         'number: '
#                                                                         '1 is '
#                                                                         'a '
#                                                                         'series '
#                                                                         'of '
#                                                                         'tables '
#                                                                         'and '
#                                                                         'text '
#                                                                         'files '
#                                                                         'associated '
#                                                                         'with '
#                                                                         'HCO '
#                                                                         'Announcement '
#                                                                         'Card '
#                                                                         'number: '
#                                                                         '1. '
#                                                                         'Compiled '
#                                                                         'by: '
#                                                                         'Harlow '
#                                                                         'Shapley. '
#                                                                         'Objects '
#                                                                         'observed '
#                                                                         'include '
#                                                                         "BLATHWAYT'S "
#                                                                         'COMET.'}],
#                                  'keywords': [{'keywordValue': 'Astronomy--Observations',
#                                                'keywordVocabulary': 'LCSH',
#                                                'keywordVocabularyURI': 'https://www.loc.gov/aba/cataloging/subject/'},
#                                               {'keywordValue': ' '
#                                                                'Astronomy--Research',
#                                                'keywordVocabulary': 'LCSH',
#                                                'keywordVocabularyURI': 'https://www.loc.gov/aba/cataloging/subject/'},
#                                               {'keywordValue': ' Astronomical '
#                                                                'observatories',
#                                                'keywordVocabulary': 'LCSH',
#                                                'keywordVocabularyURI': 'https://www.loc.gov/aba/cataloging/subject/'},
#                                               {'keywordValue': ' Variable '
#                                                                'stars',
#                                                'keywordVocabulary': 'LCSH',
#                                                'keywordVocabularyURI': 'https://www.loc.gov/aba/cataloging/subject/'},
#                                               {'keywordValue': ' Women '
#                                                                'astronomers',
#                                                'keywordVocabulary': 'LCSH',
#                                                'keywordVocabularyURI': 'https://www.loc.gov/aba/cataloging/subject/'},
#                                               {'keywordValue': ' ',
#                                                'keywordVocabulary': 'LCSH',
#                                                'keywordVocabularyURI': 'https://www.loc.gov/aba/cataloging/subject/'}],
#                                  'license': 'CC0 1.0',
#                                  'subject': ['Astronomy and Astrophysics'],
#                                  'title': 'Announcement Card number: 1',
#                                  'topic_classification': [{'topicClassValue': 'History '
#                                                                               'of '
#                                                                               'Science'},
#                                                           {'topicClassValue': ' '
#                                                                               'History '
#                                                                               'of '
#                                                                               'Astronomy'}]},
#  'Announcement Card number: 10': {'astroFacility': ['Harvard Bureau of '
#                                                     'Astronomical Telegrams'],
#                                   'astroObject': [{'objectValue': 'COMAS '
#                                                                   "SOLA'S "
#                                                                   'COMET'}],
#                                   'author': [{'authorAffiliation': 'Harvard '
#                                                                    'Library',
#                                               'authorName': 'Mika, Katherine'}],
#                                   'contact': [{'datasetContactAffiliation': 'Harvard '
#                                                                             'Library',
#                                                'datasetContactEmail': 'katherine_mika@harvard.edu',
#                                                'datasetContactName': 'Mika, '
#                                                                      'Katherine'}],
#                                   'creation_date': '1926-11-11',
#                                   'data_source': [nan],
#                                   'description': [{'dsDescriptionValue': 'Announcement '
#                                                                          'Card '
#                                                                          'number: '
#                                                                          '10 '
#                                                                          'is a '
#                                                                          'series '
#                                                                          'of '
#                                                                          'tables '
#                                                                          'and '
#                                                                          'text '
#                                                                          'files '
#                                                                          'associated '
#                                                                          'with '
#                                                                          'HCO '
#                                                                          'Announcement '
#                                                                          'Card '
#                                                                          'number: '
#                                                                          '10. '
#                                                                          'Compiled '
#                                                                          'by: '
#                                                                          'Harlow '
#                                                                          'Shapley. '
#                                                                          'Objects '
#                                                                          'observed '
#                                                                          'include '
#                                                                          'COMAS '
#                                                                          "SOLA'S "
#                                                                          'COMET.'}],
#                                   'keywords': [{'keywordValue': 'Astronomy--Observations',
#                                                 'keywordVocabulary': 'LCSH',
#                                                 'keywordVocabularyURI': 'https://www.loc.gov/aba/cataloging/subject/'},
#                                                {'keywordValue': ' '
#                                                                 'Astronomy--Research',
#                                                 'keywordVocabulary': 'LCSH',
#                                                 'keywordVocabularyURI': 'https://www.loc.gov/aba/cataloging/subject/'},
#                                                {'keywordValue': ' Astronomical '
#                                                                 'observatories',
#                                                 'keywordVocabulary': 'LCSH',
#                                                 'keywordVocabularyURI': 'https://www.loc.gov/aba/cataloging/subject/'},
#                                                {'keywordValue': ' Variable '
#                                                                 'stars',
#                                                 'keywordVocabulary': 'LCSH',
#                                                 'keywordVocabularyURI': 'https://www.loc.gov/aba/cataloging/subject/'},
#                                                {'keywordValue': ' Women '
#                                                                 'astronomers',
#                                                 'keywordVocabulary': 'LCSH',
#                                                 'keywordVocabularyURI': 'https://www.loc.gov/aba/cataloging/subject/'},
#                                                {'keywordValue': ' ',
#                                                 'keywordVocabulary': 'LCSH',
#                                                 'keywordVocabularyURI': 'https://www.loc.gov/aba/cataloging/subject/'}],
#                                   'license': 'CC0 1.0',
#                                   'subject': ['Astronomy and Astrophysics'],
#                                   'title': 'Announcement Card number: 10',
#                                   'topic_classification': [{'topicClassValue': 'History '
#                                                                                'of '
#                                                                                'Science'},
#                                                            {'topicClassValue': ' '
#                                                                                'History '
#                                                                                'of '
#                                                                                'Astronomy'}]},
#  'Announcement Card number: 11': {'astroFacility': ['Harvard Bureau of '
#                                                     'Astronomical Telegrams'],
#                                   'astroObject': [{'objectValue': 'ORBIT OF '
#                                                                   'COMAS '
#                                                                   "SOLA'S "
#                                                                   'CCOMET'}],
#                                   'author': [{'authorAffiliation': 'Harvard '
#                                                                    'Library',
#                                               'authorName': 'Mika, Katherine'}],
#                                   'contact': [{'datasetContactAffiliation': 'Harvard '
#                                                                             'Library',
#                                                'datasetContactEmail': 'katherine_mika@harvard.edu',
#                                                'datasetContactName': 'Mika, '
#                                                                      'Katherine'}],
#                                   'creation_date': '1926-11-12',
#                                   'data_source': [nan],
#                                   'description': [{'dsDescriptionValue': 'Announcement '
#                                                                          'Card '
#                                                                          'number: '
#                                                                          '11 '
#                                                                          'is a '
#                                                                          'series '
#                                                                          'of '
#                                                                          'tables '
#                                                                          'and '
#                                                                          'text '
#                                                                          'files '
#                                                                          'associated '
#                                                                          'with '
#                                                                          'HCO '
#                                                                          'Announcement '
#                                                                          'Card '
#                                                                          'number: '
#                                                                          '11. '
#                                                                          'Compiled '
#                                                                          'by: '
#                                                                          'Harlow '
#                                                                          'Shapley. '
#                                                                          'Objects '
#                                                                          'observed '
#                                                                          'include '
#                                                                          'ORBIT '
#                                                                          'OF '
#                                                                          'COMAS '
#                                                                          "SOLA'S "
#                                                                          'CCOMET.'}],
#                                   'keywords': [{'keywordValue': 'Astronomy--Observations',
#                                                 'keywordVocabulary': 'LCSH',
#                                                 'keywordVocabularyURI': 'https://www.loc.gov/aba/cataloging/subject/'},
#                                                {'keywordValue': ' '
#                                                                 'Astronomy--Research',
#                                                 'keywordVocabulary': 'LCSH',
#                                                 'keywordVocabularyURI': 'https://www.loc.gov/aba/cataloging/subject/'},
#                                                {'keywordValue': ' Astronomical '
#                                                                 'observatories',
#                                                 'keywordVocabulary': 'LCSH',
#                                                 'keywordVocabularyURI': 'https://www.loc.gov/aba/cataloging/subject/'},
#                                                {'keywordValue': ' Variable '
#                                                                 'stars',
#                                                 'keywordVocabulary': 'LCSH',
#                                                 'keywordVocabularyURI': 'https://www.loc.gov/aba/cataloging/subject/'},
#                                                {'keywordValue': ' Women '
#                                                                 'astronomers',
#                                                 'keywordVocabulary': 'LCSH',
#                                                 'keywordVocabularyURI': 'https://www.loc.gov/aba/cataloging/subject/'},
#                                                {'keywordValue': ' ',
#                                                 'keywordVocabulary': 'LCSH',
#                                                 'keywordVocabularyURI': 'https://www.loc.gov/aba/cataloging/subject/'}],
#                                   'license': 'CC0 1.0',
#                                   'subject': ['Astronomy and Astrophysics'],
#                                   'title': 'Announcement Card number: 11',
#                                   'topic_classification': [{'topicClassValue': 'History '
#                                                                                'of '
#                                                                                'Science'},
#                                                            {'topicClassValue': ' '
#                                                                                'History '
#                                                                                'of '
#                                                                                'Astronomy'}]},
#  'Announcement Card number: 12': {'astroFacility': ['Harvard Bureau of '
#                                                     'Astronomical Telegrams'],
#                                   'astroObject': [{'objectValue': 'COMAS '
#                                                                   "SOLA'S "
#                                                                   'COMET'}],
#                                   'author': [{'authorAffiliation': 'Harvard '
#                                                                    'Library',
#                                               'authorName': 'Mika, Katherine'}],
#                                   'contact': [{'datasetContactAffiliation': 'Harvard '
#                                                                             'Library',
#                                                'datasetContactEmail': 'katherine_mika@harvard.edu',
#                                                'datasetContactName': 'Mika, '
#                                                                      'Katherine'}],
#                                   'creation_date': '1926-11-15',
#                                   'data_source': [nan],
#                                   'description': [{'dsDescriptionValue': 'Announcement '
#                                                                          'Card '
#                                                                          'number: '
#                                                                          '12 '
#                                                                          'is a '
#                                                                          'series '
#                                                                          'of '
#                                                                          'tables '
#                                                                          'and '
#                                                                          'text '
#                                                                          'files '
#                                                                          'associated '
#                                                                          'with '
#                                                                          'HCO '
#                                                                          'Announcement '
#                                                                          'Card '
#                                                                          'number: '
#                                                                          '12. '
#                                                                          'Compiled '
#                                                                          'by: '
#                                                                          'Harlow '
#                                                                          'Shapley. '
#                                                                          'Objects '
#                                                                          'observed '
#                                                                          'include '
#                                                                          'COMAS '
#                                                                          "SOLA'S "
#                                                                          'COMET.'}],
#                                   'keywords': [{'keywordValue': 'Astronomy--Observations',
#                                                 'keywordVocabulary': 'LCSH',
#                                                 'keywordVocabularyURI': 'https://www.loc.gov/aba/cataloging/subject/'},
#                                                {'keywordValue': ' '
#                                                                 'Astronomy--Research',
#                                                 'keywordVocabulary': 'LCSH',
#                                                 'keywordVocabularyURI': 'https://www.loc.gov/aba/cataloging/subject/'},
#                                                {'keywordValue': ' Astronomical '
#                                                                 'observatories',
#                                                 'keywordVocabulary': 'LCSH',
#                                                 'keywordVocabularyURI': 'https://www.loc.gov/aba/cataloging/subject/'},
#                                                {'keywordValue': ' Variable '
#                                                                 'stars',
#                                                 'keywordVocabulary': 'LCSH',
#                                                 'keywordVocabularyURI': 'https://www.loc.gov/aba/cataloging/subject/'},
#                                                {'keywordValue': ' Women '
#                                                                 'astronomers',
#                                                 'keywordVocabulary': 'LCSH',
#                                                 'keywordVocabularyURI': 'https://www.loc.gov/aba/cataloging/subject/'},
#                                                {'keywordValue': ' ',
#                                                 'keywordVocabulary': 'LCSH',
#                                                 'keywordVocabularyURI': 'https://www.loc.gov/aba/cataloging/subject/'}],
#                                   'license': 'CC0 1.0',
#                                   'subject': ['Astronomy and Astrophysics'],
#                                   'title': 'Announcement Card number: 12',
#                                   'topic_classification': [{'topicClassValue': 'History '
#                                                                                'of '
#                                                                                'Science'},
#                                                            {'topicClassValue': ' '
#                                                                                'History '
#                                                                                'of '
#                                                                                'Astronomy'}]},
#  'Announcement Card number: 13': {'astroFacility': ['Harvard Bureau of '
#                                                     'Astronomical Telegrams'],
#                                   'astroObject': [{'objectValue': 'COMAS '
#                                                                   "SOLA'S "
#                                                                   'COMET (1926 '
#                                                                   'f)'}],
#                                   'author': [{'authorAffiliation': 'Harvard '
#                                                                    'Library',
#                                               'authorName': 'Mika, Katherine'}],
#                                   'contact': [{'datasetContactAffiliation': 'Harvard '
#                                                                             'Library',
#                                                'datasetContactEmail': 'katherine_mika@harvard.edu',
#                                                'datasetContactName': 'Mika, '
#                                                                      'Katherine'}],
#                                   'creation_date': '1926-12-15',
#                                   'data_source': [nan],
#                                   'description': [{'dsDescriptionValue': 'Announcement '
#                                                                          'Card '
#                                                                          'number: '
#                                                                          '13 '
#                                                                          'is a '
#                                                                          'series '
#                                                                          'of '
#                                                                          'tables '
#                                                                          'and '
#                                                                          'text '
#                                                                          'files '
#                                                                          'associated '
#                                                                          'with '
#                                                                          'HCO '
#                                                                          'Announcement '
#                                                                          'Card '
#                                                                          'number: '
#                                                                          '13. '
#                                                                          'Compiled '
#                                                                          'by: '
#                                                                          'Harlow '
#                                                                          'Shapley. '
#                                                                          'Objects '
#                                                                          'observed '
#                                                                          'include '
#                                                                          'COMAS '
#                                                                          "SOLA'S "
#                                                                          'COMET '
#                                                                          '(1926 '
#                                                                          'f).'}],
#                                   'keywords': [{'keywordValue': 'Astronomy--Observations',
#                                                 'keywordVocabulary': 'LCSH',
#                                                 'keywordVocabularyURI': 'https://www.loc.gov/aba/cataloging/subject/'},
#                                                {'keywordValue': ' '
#                                                                 'Astronomy--Research',
#                                                 'keywordVocabulary': 'LCSH',
#                                                 'keywordVocabularyURI': 'https://www.loc.gov/aba/cataloging/subject/'},
#                                                {'keywordValue': ' Astronomical '
#                                                                 'observatories',
#                                                 'keywordVocabulary': 'LCSH',
#                                                 'keywordVocabularyURI': 'https://www.loc.gov/aba/cataloging/subject/'},
#                                                {'keywordValue': ' Variable '
#                                                                 'stars',
#                                                 'keywordVocabulary': 'LCSH',
#                                                 'keywordVocabularyURI': 'https://www.loc.gov/aba/cataloging/subject/'},
#                                                {'keywordValue': ' Women '
#                                                                 'astronomers',
#                                                 'keywordVocabulary': 'LCSH',
#                                                 'keywordVocabularyURI': 'https://www.loc.gov/aba/cataloging/subject/'},
#                                                {'keywordValue': ' ',
#                                                 'keywordVocabulary': 'LCSH',
#                                                 'keywordVocabularyURI': 'https://www.loc.gov/aba/cataloging/subject/'}],
#                                   'license': 'CC0 1.0',
#                                   'subject': ['Astronomy and Astrophysics'],
#                                   'title': 'Announcement Card number: 13',
#                                   'topic_classification': [{'topicClassValue': 'History '
#                                                                                'of '
#                                                                                'Science'},
#                                                            {'topicClassValue': ' '
#                                                                                'History '
#                                                                                'of '
#                                                                                'Astronomy'}]},
#  'Announcement Card number: 2': {'astroFacility': ['Harvard Bureau of '
#                                                    'Astronomical Telegrams'],
#                                  'astroObject': [{'objectValue': "ENSOR'S "
#                                                                  'COMET'},
#                                                  {'objectValue': " BLATHWAYT'S "
#                                                                  'COMET'}],
#                                  'author': [{'authorAffiliation': 'Harvard '
#                                                                   'Library',
#                                              'authorName': 'Mika, Katherine'}],
#                                  'contact': [{'datasetContactAffiliation': 'Harvard '
#                                                                            'Library',
#                                               'datasetContactEmail': 'katherine_mika@harvard.edu',
#                                               'datasetContactName': 'Mika, '
#                                                                     'Katherine'}],
#                                  'creation_date': '1926-3-18',
#                                  'data_source': ['http://tamkin2.eps.harvard.edu/IAUCs/HAC0002.jpg'],
#                                  'description': [{'dsDescriptionValue': 'Announcement '
#                                                                         'Card '
#                                                                         'number: '
#                                                                         '2 is '
#                                                                         'a '
#                                                                         'series '
#                                                                         'of '
#                                                                         'tables '
#                                                                         'and '
#                                                                         'text '
#                                                                         'files '
#                                                                         'associated '
#                                                                         'with '
#                                                                         'HCO '
#                                                                         'Announcement '
#                                                                         'Card '
#                                                                         'number: '
#                                                                         '2. '
#                                                                         'Compiled '
#                                                                         'by: '
#                                                                         'Harlow '
#                                                                         'Shapley. '
#                                                                         'Objects '
#                                                                         'observed '
#                                                                         'include '
#                                                                         "ENSOR'S "
#                                                                         'COMET; '
#                                                                         "BLATHWAYT'S "
#                                                                         'COMET.'}],
#                                  'keywords': [{'keywordValue': 'Astronomy--Observations',
#                                                'keywordVocabulary': 'LCSH',
#                                                'keywordVocabularyURI': 'https://www.loc.gov/aba/cataloging/subject/'},
#                                               {'keywordValue': ' '
#                                                                'Astronomy--Research',
#                                                'keywordVocabulary': 'LCSH',
#                                                'keywordVocabularyURI': 'https://www.loc.gov/aba/cataloging/subject/'},
#                                               {'keywordValue': ' Astronomical '
#                                                                'observatories',
#                                                'keywordVocabulary': 'LCSH',
#                                                'keywordVocabularyURI': 'https://www.loc.gov/aba/cataloging/subject/'},
#                                               {'keywordValue': ' Variable '
#                                                                'stars',
#                                                'keywordVocabulary': 'LCSH',
#                                                'keywordVocabularyURI': 'https://www.loc.gov/aba/cataloging/subject/'},
#                                               {'keywordValue': ' Women '
#                                                                'astronomers',
#                                                'keywordVocabulary': 'LCSH',
#                                                'keywordVocabularyURI': 'https://www.loc.gov/aba/cataloging/subject/'},
#                                               {'keywordValue': ' ',
#                                                'keywordVocabulary': 'LCSH',
#                                                'keywordVocabularyURI': 'https://www.loc.gov/aba/cataloging/subject/'}],
#                                  'license': 'CC0 1.0',
#                                  'subject': ['Astronomy and Astrophysics'],
#                                  'title': 'Announcement Card number: 2',
#                                  'topic_classification': [{'topicClassValue': 'History '
#                                                                               'of '
#                                                                               'Science'},
#                                                           {'topicClassValue': ' '
#                                                                               'History '
#                                                                               'of '
#                                                                               'Astronomy'}]},
#  'Announcement Card number: 3': {'astroFacility': ['Harvard Bureau of '
#                                                    'Astronomical Telegrams'],
#                                  'astroObject': [],
#                                  'author': [{'authorAffiliation': 'Harvard '
#                                                                   'Library',
#                                              'authorName': 'Mika, Katherine'}],
#                                  'contact': [{'datasetContactAffiliation': 'Harvard '
#                                                                            'Library',
#                                               'datasetContactEmail': 'katherine_mika@harvard.edu',
#                                               'datasetContactName': 'Mika, '
#                                                                     'Katherine'}],
#                                  'creation_date': '1926-5-15',
#                                  'data_source': [nan],
#                                  'description': [{'dsDescriptionValue': 'Announcement '
#                                                                         'Card '
#                                                                         'number: '
#                                                                         '3 is '
#                                                                         'a '
#                                                                         'series '
#                                                                         'of '
#                                                                         'tables '
#                                                                         'and '
#                                                                         'text '
#                                                                         'files '
#                                                                         'associated '
#                                                                         'with '
#                                                                         'HCO '
#                                                                         'Announcement '
#                                                                         'Card '
#                                                                         'number: '
#                                                                         '3. '
#                                                                         'Compiled '
#                                                                         'by: '
#                                                                         'Harlow '
#                                                                         'Shapley. '
#                                                                         'Objects '
#                                                                         'observed '
#                                                                         'include '
#                                                                         'nan.'}],
#                                  'keywords': [{'keywordValue': 'Astronomy--Observations',
#                                                'keywordVocabulary': 'LCSH',
#                                                'keywordVocabularyURI': 'https://www.loc.gov/aba/cataloging/subject/'},
#                                               {'keywordValue': ' '
#                                                                'Astronomy--Research',
#                                                'keywordVocabulary': 'LCSH',
#                                                'keywordVocabularyURI': 'https://www.loc.gov/aba/cataloging/subject/'},
#                                               {'keywordValue': ' Astronomical '
#                                                                'observatories',
#                                                'keywordVocabulary': 'LCSH',
#                                                'keywordVocabularyURI': 'https://www.loc.gov/aba/cataloging/subject/'},
#                                               {'keywordValue': ' Variable '
#                                                                'stars',
#                                                'keywordVocabulary': 'LCSH',
#                                                'keywordVocabularyURI': 'https://www.loc.gov/aba/cataloging/subject/'},
#                                               {'keywordValue': ' Women '
#                                                                'astronomers',
#                                                'keywordVocabulary': 'LCSH',
#                                                'keywordVocabularyURI': 'https://www.loc.gov/aba/cataloging/subject/'},
#                                               {'keywordValue': ' ',
#                                                'keywordVocabulary': 'LCSH',
#                                                'keywordVocabularyURI': 'https://www.loc.gov/aba/cataloging/subject/'}],
#                                  'license': 'CC0 1.0',
#                                  'subject': ['Astronomy and Astrophysics'],
#                                  'title': 'Announcement Card number: 3',
#                                  'topic_classification': [{'topicClassValue': 'History '
#                                                                               'of '
#                                                                               'Science'},
#                                                           {'topicClassValue': ' '
#                                                                               'History '
#                                                                               'of '
#                                                                               'Astronomy'}]},
#  'Announcement Card number: 4': {'astroFacility': ['Harvard Bureau of '
#                                                    'Astronomical Telegrams'],
#                                  'astroObject': [{'objectValue': "KOPFF'S "
#                                                                  'COMET '
#                                                                  '(1906-IV)'}],
#                                  'author': [{'authorAffiliation': 'Harvard '
#                                                                   'Library',
#                                              'authorName': 'Mika, Katherine'}],
#                                  'contact': [{'datasetContactAffiliation': 'Harvard '
#                                                                            'Library',
#                                               'datasetContactEmail': 'katherine_mika@harvard.edu',
#                                               'datasetContactName': 'Mika, '
#                                                                     'Katherine'}],
#                                  'creation_date': '1926-7-15',
#                                  'data_source': [nan],
#                                  'description': [{'dsDescriptionValue': 'Announcement '
#                                                                         'Card '
#                                                                         'number: '
#                                                                         '4 is '
#                                                                         'a '
#                                                                         'series '
#                                                                         'of '
#                                                                         'tables '
#                                                                         'and '
#                                                                         'text '
#                                                                         'files '
#                                                                         'associated '
#                                                                         'with '
#                                                                         'HCO '
#                                                                         'Announcement '
#                                                                         'Card '
#                                                                         'number: '
#                                                                         '4. '
#                                                                         'Compiled '
#                                                                         'by: '
#                                                                         'Harlow '
#                                                                         'Shapley. '
#                                                                         'Objects '
#                                                                         'observed '
#                                                                         'include '
#                                                                         "KOPFF'S "
#                                                                         'COMET '
#                                                                         '(1906-IV).'}],
#                                  'keywords': [{'keywordValue': 'Astronomy--Observations',
#                                                'keywordVocabulary': 'LCSH',
#                                                'keywordVocabularyURI': 'https://www.loc.gov/aba/cataloging/subject/'},
#                                               {'keywordValue': ' '
#                                                                'Astronomy--Research',
#                                                'keywordVocabulary': 'LCSH',
# ...
#                                                                         'Objects '
#                                                                         'observed '
#                                                                         'include '
#                                                                         'GIACOBINI-ZINNER '
#                                                                         'COMET '
#                                                                         '(1900 '
#                                                                         'III, '
#                                                                         '1913 '
#                                                                         'e).'}],
#                                  'keywords': [{'keywordValue': 'Astronomy--Observations',
#                                                'keywordVocabulary': 'LCSH',
#                                                'keywordVocabularyURI': 'https://www.loc.gov/aba/cataloging/subject/'},
#                                               {'keywordValue': ' '
#                                                                'Astronomy--Research',
#                                                'keywordVocabulary': 'LCSH',
#                                                'keywordVocabularyURI': 'https://www.loc.gov/aba/cataloging/subject/'},
#                                               {'keywordValue': ' Astronomical '
#                                                                'observatories',
#                                                'keywordVocabulary': 'LCSH',
#                                                'keywordVocabularyURI': 'https://www.loc.gov/aba/cataloging/subject/'},
#                                               {'keywordValue': ' Variable '
#                                                                'stars',
#                                                'keywordVocabulary': 'LCSH',
#                                                'keywordVocabularyURI': 'https://www.loc.gov/aba/cataloging/subject/'},
#                                               {'keywordValue': ' Women '
#                                                                'astronomers',
#                                                'keywordVocabulary': 'LCSH',
#                                                'keywordVocabularyURI': 'https://www.loc.gov/aba/cataloging/subject/'},
#                                               {'keywordValue': ' ',
#                                                'keywordVocabulary': 'LCSH',
#                                                'keywordVocabularyURI': 'https://www.loc.gov/aba/cataloging/subject/'}],
#                                  'license': 'CC0 1.0',
#                                  'subject': ['Astronomy and Astrophysics'],
#                                  'title': 'Announcement Card number: 7',
#                                  'topic_classification': [{'topicClassValue': 'History '
#                                                                               'of '
#                                                                               'Science'},
#                                                           {'topicClassValue': ' '
#                                                                               'History '
#                                                                               'of '
#                                                                               'Astronomy'}]},
#  'Announcement Card number: 8': {'astroFacility': ['Harvard Bureau of '
#                                                    'Astronomical Telegrams'],
#                                  'astroObject': [{'objectValue': 'New Comet'},
#                                                  {'objectValue': " NEUJMIN'S "
#                                                                  'COMET'}],
#                                  'author': [{'authorAffiliation': 'Harvard '
#                                                                   'Library',
#                                              'authorName': 'Mika, Katherine'}],
#                                  'contact': [{'datasetContactAffiliation': 'Harvard '
#                                                                            'Library',
#                                               'datasetContactEmail': 'katherine_mika@harvard.edu',
#                                               'datasetContactName': 'Mika, '
#                                                                     'Katherine'}],
#                                  'creation_date': '1926-11-8',
#                                  'data_source': [nan],
#                                  'description': [{'dsDescriptionValue': 'Announcement '
#                                                                         'Card '
#                                                                         'number: '
#                                                                         '8 is '
#                                                                         'a '
#                                                                         'series '
#                                                                         'of '
#                                                                         'tables '
#                                                                         'and '
#                                                                         'text '
#                                                                         'files '
#                                                                         'associated '
#                                                                         'with '
#                                                                         'HCO '
#                                                                         'Announcement '
#                                                                         'Card '
#                                                                         'number: '
#                                                                         '8. '
#                                                                         'Compiled '
#                                                                         'by: '
#                                                                         'Harlow '
#                                                                         'Shapley. '
#                                                                         'Objects '
#                                                                         'observed '
#                                                                         'include '
#                                                                         'New '
#                                                                         'Comet; '
#                                                                         "NEUJMIN'S "
#                                                                         'COMET.'}],
#                                  'keywords': [{'keywordValue': 'Astronomy--Observations',
#                                                'keywordVocabulary': 'LCSH',
#                                                'keywordVocabularyURI': 'https://www.loc.gov/aba/cataloging/subject/'},
#                                               {'keywordValue': ' '
#                                                                'Astronomy--Research',
#                                                'keywordVocabulary': 'LCSH',
#                                                'keywordVocabularyURI': 'https://www.loc.gov/aba/cataloging/subject/'},
#                                               {'keywordValue': ' Astronomical '
#                                                                'observatories',
#                                                'keywordVocabulary': 'LCSH',
#                                                'keywordVocabularyURI': 'https://www.loc.gov/aba/cataloging/subject/'},
#                                               {'keywordValue': ' Variable '
#                                                                'stars',
#                                                'keywordVocabulary': 'LCSH',
#                                                'keywordVocabularyURI': 'https://www.loc.gov/aba/cataloging/subject/'},
#                                               {'keywordValue': ' Women '
#                                                                'astronomers',
#                                                'keywordVocabulary': 'LCSH',
#                                                'keywordVocabularyURI': 'https://www.loc.gov/aba/cataloging/subject/'},
#                                               {'keywordValue': ' ',
#                                                'keywordVocabulary': 'LCSH',
#                                                'keywordVocabularyURI': 'https://www.loc.gov/aba/cataloging/subject/'}],
#                                  'license': 'CC0 1.0',
#                                  'subject': ['Astronomy and Astrophysics'],
#                                  'title': 'Announcement Card number: 8',
#                                  'topic_classification': [{'topicClassValue': 'History '
#                                                                               'of '
#                                                                               'Science'},
#                                                           {'topicClassValue': ' '
#                                                                               'History '
#                                                                               'of '
#                                                                               'Astronomy'}]},
#  'Announcement Card number: 9': {'astroFacility': ['Harvard Bureau of '
#                                                    'Astronomical Telegrams'],
#                                  'astroObject': [{'objectValue': "COMAS SOLA'S "
#                                                                  'COMET'}],
#                                  'author': [{'authorAffiliation': 'Harvard '
#                                                                   'Library',
#                                              'authorName': 'Mika, Katherine'}],
#                                  'contact': [{'datasetContactAffiliation': 'Harvard '
#                                                                            'Library',
#                                               'datasetContactEmail': 'katherine_mika@harvard.edu',
#                                               'datasetContactName': 'Mika, '
#                                                                     'Katherine'}],
#                                  'creation_date': '1920-11-10',
#                                  'data_source': [nan],
#                                  'description': [{'dsDescriptionValue': 'Announcement '
#                                                                         'Card '
#                                                                         'number: '
#                                                                         '9 is '
#                                                                         'a '
#                                                                         'series '
#                                                                         'of '
#                                                                         'tables '
#                                                                         'and '
#                                                                         'text '
#                                                                         'files '
#                                                                         'associated '
#                                                                         'with '
#                                                                         'HCO '
#                                                                         'Announcement '
#                                                                         'Card '
#                                                                         'number: '
#                                                                         '9. '
#                                                                         'Compiled '
#                                                                         'by: '
#                                                                         'Harlow '
#                                                                         'Shapley. '
#                                                                         'Objects '
#                                                                         'observed '
#                                                                         'include '
#                                                                         'COMAS '
#                                                                         "SOLA'S "
#                                                                         'COMET.'}],
#                                  'keywords': [{'keywordValue': 'Astronomy--Observations',
#                                                'keywordVocabulary': 'LCSH',
#                                                'keywordVocabularyURI': 'https://www.loc.gov/aba/cataloging/subject/'},
#                                               {'keywordValue': ' '
#                                                                'Astronomy--Research',
#                                                'keywordVocabulary': 'LCSH',
#                                                'keywordVocabularyURI': 'https://www.loc.gov/aba/cataloging/subject/'},
#                                               {'keywordValue': ' Astronomical '
#                                                                'observatories',
#                                                'keywordVocabulary': 'LCSH',
#                                                'keywordVocabularyURI': 'https://www.loc.gov/aba/cataloging/subject/'},
#                                               {'keywordValue': ' Variable '
#                                                                'stars',
#                                                'keywordVocabulary': 'LCSH',
#                                                'keywordVocabularyURI': 'https://www.loc.gov/aba/cataloging/subject/'},
#                                               {'keywordValue': ' Women '
#                                                                'astronomers',
#                                                'keywordVocabulary': 'LCSH',
#                                                'keywordVocabularyURI': 'https://www.loc.gov/aba/cataloging/subject/'},
#                                               {'keywordValue': ' ',
#                                                'keywordVocabulary': 'LCSH',
#                                                'keywordVocabularyURI': 'https://www.loc.gov/aba/cataloging/subject/'}],
#                                  'license': 'CC0 1.0',
#                                  'subject': ['Astronomy and Astrophysics'],
#                                  'title': 'Announcement Card number: 9',
#                                  'topic_classification': [{'topicClassValue': 'History '
#                                                                               'of '
#                                                                               'Science'},
#                                                           {'topicClassValue': ' '
#                                                                               'History '
#                                                                               'of '
#                                                                               'Astronomy'}]}}

# %% [markdown]
# ### 1.4 Create Datafile Metadata
# - Create a `dict` of `DataFrames` containing metadata about individual files

# %%
for series_name in g_series_names:
    # get dataset metadata for the series
    series_metadata = g_dataset_metadata[series_name]
    # get the series inventory
    series_inventory_df = g_series_inventories[series_name]
    # create datafile metadata
    g_datafile_metadata[series_name] = curate.create_datafile_metadata(series_inventory_df,
                                                                       g_datafile_description_template_csv,
                                                                       g_datafile_description_template_txt,
                                                                       g_datafile_description_template_xml)

# %%
g_datafile_metadata['Announcement Card number: 3']
# Out:
#                                 filename file_type  \
# 0  HCOAnnouncement0001_0003.innodata.xml       xml
# 1  HCOAnnouncement0001_0003.innodata.jpg       jpg
# 2  HCOAnnouncement0001_0003.innodata.txt       txt
#
#                                          description         mimetype  \
# 0  File contains xml tree with OCR bounding box d...  application/xml
# 1  File contains OCR text with data from Announce...          UNKNOWN
# 2  File contains OCR text with data from Announce...       text/plain
#
#        tags
# 0  ["Data"]
# 1  ["Data"]
# 2  ["Data"]

# %% [markdown]
# ### 1.4 Create Series Batches
# - Create a set of (approximately) equal length batches of series (to create dataset and upload datafiles)
# - Generally, there are too many series in a volume to create the related datasets and then upload all their datafiles in a single tight loop. Therefore, it's useful to create batches of these series and perform the create/upload operation on a single batch at a time.

# %%
# max number of series in a batch
batch_size = 3
g_batches = np.array_split(g_series_names, len(g_series_names)/batch_size)
pprint.pprint(g_batches)
# Out:
# [array(['Announcement Card number: 1', 'Announcement Card number: 2',
#        'Announcement Card number: 3', 'Announcement Card number: 4'],
#       dtype='<U28'),
#  array(['Announcement Card number: 5', 'Announcement Card number: 6',
#        'Announcement Card number: 7'], dtype='<U28'),
#  array(['Announcement Card number: 8', 'Announcement Card number: 9',
#        'Announcement Card number: 10'], dtype='<U28'),
#  array(['Announcement Card number: 11', 'Announcement Card number: 12',
#        'Announcement Card number: 13'], dtype='<U28')]

# %% [markdown]
# ### 2. Initialize `pyDataverse` API
# - Use `pyDataverse` to initialize the API to the dataverse installation

# %%
# set pyDataverse API adapter
g_api = NativeApi(g_dataverse_installation_url, g_dataverse_api_key)

# print results
print('{}'.format(g_api))
# Out:
# Native API: https://demo.dataverse.org/api/v1

# %% [markdown]
# ### 3. Create Datasets and Upload Datafiles

# %% [markdown]
# #### 3.1 Create all datasets
# - For each series name, create a dataset and retain status information

# %%
# for each series, create a dataset and save its information
for series_name in g_series_names:
    # get the series metadata
    series_metadata = g_dataset_metadata[series_name]
    # create the dataset
    g_dataverse_dataset_info[series_name] = curate.create_dataset(g_api, g_dataverse_collection, series_metadata)

pprint.pprint(g_dataverse_dataset_info)

# %%
for series_name in g_series_names:
    # get dataset metadata for the series
    series_metadata = g_dataset_metadata[series_name]

# %% [markdown]
# #### 3.1.1 Get dataset PIDs from HDV collection
#
# For use if datasets have been previously created

# %%
#only necessary if you made changes to the curate module before this section
import importlib
importlib.reload(curate)

# %%
g_dataverse_dataset_info = get_dataset_pids_from_hdv(g_api, g_dataverse_collection)

# %%
pprint.pprint(g_dataverse_dataset_info)

# %% [markdown]
# #### 3.2 Upload dataset datafiles, one batch at a time
# - Upload the datafiles associated with each dataset in a batch
# - *MAKE SURE DIRECT UPLOAD IS ENABLED*
# - problem with "registering files" in dvuploader python library. Usually throws 500 error, but works with small number of files (eg. 1925 Kiaochow). Indexing issue?
# - Try looping batches with exception for 500 error (add in pause)

# %%
index = 0
batch = g_batches[index]
pids = get_dataset_pids(batch, g_dataverse_dataset_info)
datafile_metadata = get_datafile_inventories(batch, g_datafile_metadata)
print('Uploading batch: {}, series: {}'.format(index, batch))
ret = upload_files_batch_errors(g_api, g_dataverse_installation_url, batch, pids, g_datafiles_path, datafile_metadata)

# %%
index = 42
batch = g_batches[index]
pids = get_dataset_pids(batch, g_dataverse_dataset_info)
datafile_metadata = get_datafile_inventories(batch, g_datafile_metadata)
print('Uploading batch: {}, series: {}'.format(index, batch))
upload_files_batch(g_api, g_dataverse_installation_url, batch, pids, g_datafiles_path, datafile_metadata)

# %% [markdown]
# #### 3.3 Publish datasets

# %%
# create dataset
import importlib
importlib.reload(curate)

# publish the datasets
errors = curate.publish_datasets(g_api, g_dataverse_collection, version='major')

pprint.pprint(errors)

# %% [markdown]
# ## Create Inventories
#
# combine metadata files into single, long dataframe

# %%
base_dir = "/Users/katherinemika/Desktop/curation/historic_datasets/"
annual_trade_reports_1923 = base_dir + 'annual_trade_reports/1923/1923_metadata.csv'
annual_trade_reports_1924 = base_dir + 'annual_trade_reports/1924/1924_metadata.csv'
annual_trade_reports_1925 = base_dir + 'annual_trade_reports/1925/1925_metadata.csv'
annual_trade_reports_1926 = base_dir + 'annual_trade_reports/1926/1926_metadata.csv'
annual_trade_reports_1927 = base_dir + 'annual_trade_reports/1927/1927_metadata.csv'
annual_trade_reports_1928 = base_dir + 'annual_trade_reports/1928/1928_metadata.csv'
returns_trade_ports = base_dir + 'returns_trade_ports/1866/1866_returns_trades_ports_metadata.csv'
shanghai_returns = base_dir + 'shanghai_returns/1936/1936_shanghai_returns_metadata.csv'
trade_statistics_treaty_ports = base_dir + 'trade_statistics_treaty_ports/1873/1873_metadata.csv'

# %%
with open(annual_trade_reports_1923, 'rb') as f: 
    result = chardet.detect(f.read())
    encoding = result['encoding']
    print(f"detected encoding: {encoding}")
    
df_annual_trade_reports_1923 = pd.read_csv(annual_trade_reports_1923,index_col=None, encoding=encoding, low_memory=False)

# %%
with open(annual_trade_reports_1924, 'rb') as f: 
    result = chardet.detect(f.read())
    encoding = result['encoding']
    print(f"detected encoding: {encoding}")
    
df_annual_trade_reports_1924 = pd.read_csv(annual_trade_reports_1924,index_col=None, encoding=encoding, low_memory=False)

# %%
with open(annual_trade_reports_1925, 'rb') as f: 
    result = chardet.detect(f.read())
    encoding = result['encoding']
    print(f"detected encoding: {encoding}")
    
df_annual_trade_reports_1925 = pd.read_csv(annual_trade_reports_1925,index_col=None, encoding=encoding, low_memory=False)

# %%
with open(annual_trade_reports_1926, 'rb') as f: 
    result = chardet.detect(f.read())
    encoding = result['encoding']
    print(f"detected encoding: {encoding}")
    
df_annual_trade_reports_1926 = pd.read_csv(annual_trade_reports_1926,index_col=None, encoding=encoding, low_memory=False)

# %%
with open(annual_trade_reports_1927, 'rb') as f: 
    result = chardet.detect(f.read())
    encoding = result['encoding']
    print(f"detected encoding: {encoding}")
    
df_annual_trade_reports_1927 = pd.read_csv(annual_trade_reports_1927,index_col=None, encoding=encoding, low_memory=False)

# %%
with open(annual_trade_reports_1928, 'rb') as f: 
    result = chardet.detect(f.read())
    encoding = result['encoding']
    print(f"detected encoding: {encoding}")
    
df_annual_trade_reports_1928 = pd.read_csv(annual_trade_reports_1928,index_col=None, encoding=encoding, low_memory=False)

# %%
with open(returns_trade_ports, 'rb') as f: 
    result = chardet.detect(f.read())
    encoding = result['encoding']
    print(f"detected encoding: {encoding}")
    
df_returns_trade_ports = pd.read_csv(returns_trade_ports,index_col=None, encoding=encoding, low_memory=False)

# %%
with open(shanghai_returns, 'rb') as f: 
    result = chardet.detect(f.read())
    encoding = result['encoding']
    print(f"detected encoding: {encoding}")
    
df_shanghai_returns = pd.read_csv(shanghai_returns,index_col=None, encoding=encoding, low_memory=False)

# %%
with open(trade_statistics_treaty_ports, 'rb') as f: 
    result = chardet.detect(f.read())
    encoding = result['encoding']
    print(f"detected encoding: {encoding}")
    
df_trade_statistics_treaty_ports = pd.read_csv(trade_statistics_treaty_ports,index_col=None, encoding=encoding, low_memory=False)

# %%
#concatenate dataframes
dfs = [df_annual_trade_reports_1923,
       df_annual_trade_reports_1924,
       df_annual_trade_reports_1925,
       df_annual_trade_reports_1926,
       df_annual_trade_reports_1927,
       df_annual_trade_reports_1928,
       df_returns_trade_ports,
       df_shanghai_returns, 
       df_trade_statistics_treaty_ports]

result = pd.concat(dfs, axis=0).reset_index(drop=True)
print(result)

# %%
result.to_csv(base_dir+ "chinese_maritime_customs_metadata_inventory.csv", index=False)

# %% [markdown]
# -----------

# %% [markdown]
# ## Test Curation Process

# %% [markdown]
# ### Test: Create a single dataset
# This test allows users to create a single dataset and upload its related datafiles.
# Useful for troubleshooting and to test other collections.

# %% [markdown]
# #### 1 Test: Create datafile metadata

# %%
# create datafile metadata
# get the first series
first_series = g_series_names[0]
first_series_metadata = g_dataset_metadata[first_series]
first_series_inventory_df = g_series_inventories[first_series]

# set the template

datafile_metadata_df = curate.create_datafile_metadata(first_series_inventory_df, g_datafile_description_template_csv, g_datafile_description_template_txt, g_datafile_description_template_xml)

# %%
first_series_metadata['journalArticleType'] = 'abstract'
first_series_metadata['astroType'] = 'Observation'
first_series_metadata['universe'] = 'The Universe'

# %%
first_series_metadata
# Out:
# {'title': 'Announcement Card number: 1',
#  'author': [{'authorName': 'Mika, Katherine',
#    'authorAffiliation': 'Harvard Library'}],
#  'description': [{'dsDescriptionValue': "Announcement Card number: 1 is a series of tables and text files associated with HCO Announcement Card number: 1. Compiled by: Harlow Shapley. Objects observed include BLATHWAYT'S COMET."}],
#  'contact': [{'datasetContactName': 'Mika, Katherine',
#    'datasetContactAffiliation': 'Harvard Library',
#    'datasetContactEmail': 'katherine_mika@harvard.edu'}],
#  'subject': ['Astronomy and Astrophysics'],
#  'license': 'CC0 1.0',
#  'keywords': [{'keywordValue': 'Astronomy--Observations',
#    'keywordVocabulary': 'LCSH',
#    'keywordVocabularyURI': 'https://www.loc.gov/aba/cataloging/subject/'},
#   {'keywordValue': ' Astronomy--Research',
#    'keywordVocabulary': 'LCSH',
#    'keywordVocabularyURI': 'https://www.loc.gov/aba/cataloging/subject/'},
#   {'keywordValue': ' Astronomical observatories',
#    'keywordVocabulary': 'LCSH',
#    'keywordVocabularyURI': 'https://www.loc.gov/aba/cataloging/subject/'},
#   {'keywordValue': ' Variable stars',
#    'keywordVocabulary': 'LCSH',
#    'keywordVocabularyURI': 'https://www.loc.gov/aba/cataloging/subject/'},
#   {'keywordValue': ' Women astronomers',
#    'keywordVocabulary': 'LCSH',
#    'keywordVocabularyURI': 'https://www.loc.gov/aba/cataloging/subject/'},
#   {'keywordValue': ' ',
#    'keywordVocabulary': 'LCSH',
#    'keywordVocabularyURI': 'https://www.loc.gov/aba/cataloging/subject/'}],
#  'topic_classification': [{'topicClassValue': 'History of Science'},
#   {'topicClassValue': ' History of Astronomy'}],
#  'data_source': ['http://tamkin2.eps.harvard.edu/IAUCs/HAC0001.jpg'],
#  'creation_date': '1926-3-12',
#  'astroObject': [{'objectValue': "BLATHWAYT'S COMET"}],
#  'astroFacility': ['Harvard Bureau of Astronomical Telegrams'],
#  'journalArticleType': 'abstract',
#  'astroType': 'Observation',
#  'universe': 'The Universe'}

# %%
from pyDataverse.models import Dataset

# %%
ds = Dataset()
ds.title = first_series_metadata.get('title')
ds.author = first_series_metadata.get('author')
ds.dsDescription =  first_series_metadata.get('description')
ds.datasetContact = first_series_metadata.get('contact')
ds.subject = first_series_metadata.get('subject')
ds.license = first_series_metadata.get('license')
ds.keyword = first_series_metadata.get('keywords')
ds.topicClassification = first_series_metadata.get('topic_classification')
ds.astroObject = first_series_metadata.get('astroObject')
ds.astroFacility = first_series_metadata.get('astroFacility')
ds.astroType = first_series_metadata.get('astroType')
ds.universe = first_series_metadata.get('universe')
ds.journalArticleType = first_series_metadata.get('journalArticleType')

#json_dataset = ds.json()
#pprint.pprint(json_dataset)

pprint.pprint(ds.json())
# Out:
# ('{\n'
#  '  "datasetVersion": {\n'
#  '    "metadataBlocks": {\n'
#  '      "citation": {\n'
#  '        "fields": [\n'
#  '          {\n'
#  '            "typeName": "subject",\n'
#  '            "multiple": true,\n'
#  '            "typeClass": "controlledVocabulary",\n'
#  '            "value": [\n'
#  '              "Astronomy and Astrophysics"\n'
#  '            ]\n'
#  '          },\n'
#  '          {\n'
#  '            "typeName": "title",\n'
#  '            "multiple": false,\n'
#  '            "typeClass": "primitive",\n'
#  '            "value": "Announcement Card number: 1"\n'
#  '          },\n'
#  '          {\n'
#  '            "typeName": "author",\n'
#  '            "multiple": true,\n'
#  '            "typeClass": "compound",\n'
#  '            "value": [\n'
#  '              {\n'
#  '                "authorName": {\n'
#  '                  "typeName": "authorName",\n'
#  '                  "typeClass": "primitive",\n'
#  '                  "multiple": false,\n'
#  '                  "value": "Mika, Katherine"\n'
#  '                },\n'
#  '                "authorAffiliation": {\n'
#  '                  "typeName": "authorAffiliation",\n'
#  '                  "typeClass": "primitive",\n'
#  '                  "multiple": false,\n'
#  '                  "value": "Harvard Library"\n'
#  '                }\n'
#  '              }\n'
#  '            ]\n'
#  '          },\n'
#  '          {\n'
#  '            "typeName": "datasetContact",\n'
#  '            "multiple": true,\n'
#  '            "typeClass": "compound",\n'
#  '            "value": [\n'
#  '              {\n'
#  '                "datasetContactName": {\n'
#  '                  "typeName": "datasetContactName",\n'
#  '                  "typeClass": "primitive",\n'
#  '                  "multiple": false,\n'
#  '                  "value": "Mika, Katherine"\n'
#  '                },\n'
#  '                "datasetContactAffiliation": {\n'
#  '                  "typeName": "datasetContactAffiliation",\n'
#  '                  "typeClass": "primitive",\n'
#  '                  "multiple": false,\n'
#  '                  "value": "Harvard Library"\n'
#  '                },\n'
#  '                "datasetContactEmail": {\n'
#  '                  "typeName": "datasetContactEmail",\n'
#  '                  "typeClass": "primitive",\n'
#  '                  "multiple": false,\n'
#  '                  "value": "katherine_mika@harvard.edu"\n'
#  '                }\n'
#  '              }\n'
#  '            ]\n'
#  '          },\n'
#  '          {\n'
#  '            "typeName": "dsDescription",\n'
#  '            "multiple": true,\n'
#  '            "typeClass": "compound",\n'
#  '            "value": [\n'
#  '              {\n'
#  '                "dsDescriptionValue": {\n'
#  '                  "typeName": "dsDescriptionValue",\n'
#  '                  "typeClass": "primitive",\n'
#  '                  "multiple": false,\n'
#  '                  "value": "Announcement Card number: 1 is a series of '
#  'tables and text files associated with HCO Announcement Card number: 1. '
#  'Compiled by: Harlow Shapley. Objects observed include BLATHWAYT\'S COMET."\n'
#  '                }\n'
#  '              }\n'
#  '            ]\n'
#  '          },\n'
#  '          {\n'
#  '            "typeName": "keyword",\n'
#  '            "multiple": true,\n'
#  '            "typeClass": "compound",\n'
#  '            "value": [\n'
#  '              {\n'
#  '                "keywordValue": {\n'
#  '                  "typeName": "keywordValue",\n'
#  '                  "typeClass": "primitive",\n'
#  '                  "multiple": false,\n'
#  '                  "value": "Astronomy--Observations"\n'
#  '                },\n'
#  '                "keywordVocabulary": {\n'
#  '                  "typeName": "keywordVocabulary",\n'
#  '                  "typeClass": "primitive",\n'
#  '                  "multiple": false,\n'
#  '                  "value": "LCSH"\n'
#  '                },\n'
#  '                "keywordVocabularyURI": {\n'
#  '                  "typeName": "keywordVocabularyURI",\n'
#  '                  "typeClass": "primitive",\n'
#  '                  "multiple": false,\n'
#  '                  "value": "https://www.loc.gov/aba/cataloging/subject/"\n'
#  '                }\n'
#  '              },\n'
#  '              {\n'
#  '                "keywordValue": {\n'
#  '                  "typeName": "keywordValue",\n'
#  '                  "typeClass": "primitive",\n'
#  '                  "multiple": false,\n'
#  '                  "value": " Astronomy--Research"\n'
#  '                },\n'
#  '                "keywordVocabulary": {\n'
#  '                  "typeName": "keywordVocabulary",\n'
#  '                  "typeClass": "primitive",\n'
#  '                  "multiple": false,\n'
#  '                  "value": "LCSH"\n'
#  '                },\n'
#  '                "keywordVocabularyURI": {\n'
#  '                  "typeName": "keywordVocabularyURI",\n'
#  '                  "typeClass": "primitive",\n'
#  '                  "multiple": false,\n'
#  '                  "value": "https://www.loc.gov/aba/cataloging/subject/"\n'
#  '                }\n'
#  '              },\n'
#  '              {\n'
#  '                "keywordValue": {\n'
#  '                  "typeName": "keywordValue",\n'
#  '                  "typeClass": "primitive",\n'
#  '                  "multiple": false,\n'
#  '                  "value": " Astronomical observatories"\n'
#  '                },\n'
#  '                "keywordVocabulary": {\n'
#  '                  "typeName": "keywordVocabulary",\n'
#  '                  "typeClass": "primitive",\n'
#  '                  "multiple": false,\n'
#  '                  "value": "LCSH"\n'
#  '                },\n'
#  '                "keywordVocabularyURI": {\n'
#  '                  "typeName": "keywordVocabularyURI",\n'
#  '                  "typeClass": "primitive",\n'
#  '                  "multiple": false,\n'
#  '                  "value": "https://www.loc.gov/aba/cataloging/subject/"\n'
#  '                }\n'
#  '              },\n'
#  '              {\n'
#  '                "keywordValue": {\n'
#  '                  "typeName": "keywordValue",\n'
#  '                  "typeClass": "primitive",\n'
#  '                  "multiple": false,\n'
#  '                  "value": " Variable stars"\n'
#  '                },\n'
#  '                "keywordVocabulary": {\n'
#  '                  "typeName": "keywordVocabulary",\n'
#  '                  "typeClass": "primitive",\n'
#  '                  "multiple": false,\n'
#  '                  "value": "LCSH"\n'
#  '                },\n'
#  '                "keywordVocabularyURI": {\n'
#  '                  "typeName": "keywordVocabularyURI",\n'
#  '                  "typeClass": "primitive",\n'
#  '                  "multiple": false,\n'
#  '                  "value": "https://www.loc.gov/aba/cataloging/subject/"\n'
#  '                }\n'
#  '              },\n'
#  '              {\n'
#  '                "keywordValue": {\n'
#  '                  "typeName": "keywordValue",\n'
#  '                  "typeClass": "primitive",\n'
#  '                  "multiple": false,\n'
#  '                  "value": " Women astronomers"\n'
#  '                },\n'
#  '                "keywordVocabulary": {\n'
#  '                  "typeName": "keywordVocabulary",\n'
#  '                  "typeClass": "primitive",\n'
#  '                  "multiple": false,\n'
#  '                  "value": "LCSH"\n'
#  '                },\n'
#  '                "keywordVocabularyURI": {\n'
#  '                  "typeName": "keywordVocabularyURI",\n'
#  '                  "typeClass": "primitive",\n'
#  '                  "multiple": false,\n'
#  '                  "value": "https://www.loc.gov/aba/cataloging/subject/"\n'
#  '                }\n'
#  '              },\n'
#  '              {\n'
#  '                "keywordValue": {\n'
#  '                  "typeName": "keywordValue",\n'
#  '                  "typeClass": "primitive",\n'
#  '                  "multiple": false,\n'
#  '                  "value": " "\n'
#  '                },\n'
#  '                "keywordVocabulary": {\n'
#  '                  "typeName": "keywordVocabulary",\n'
#  '                  "typeClass": "primitive",\n'
#  '                  "multiple": false,\n'
#  '                  "value": "LCSH"\n'
#  '                },\n'
#  '                "keywordVocabularyURI": {\n'
#  '                  "typeName": "keywordVocabularyURI",\n'
#  '                  "typeClass": "primitive",\n'
#  '                  "multiple": false,\n'
#  '                  "value": "https://www.loc.gov/aba/cataloging/subject/"\n'
#  '                }\n'
#  '              }\n'
#  '            ]\n'
#  '          },\n'
#  '          {\n'
#  '            "typeName": "topicClassification",\n'
#  '            "multiple": true,\n'
#  '            "typeClass": "compound",\n'
#  '            "value": [\n'
#  '              {\n'
#  '                "topicClassValue": {\n'
#  '                  "typeName": "topicClassValue",\n'
#  '                  "typeClass": "primitive",\n'
#  '                  "multiple": false,\n'
#  '                  "value": "History of Science"\n'
#  '                }\n'
#  '              },\n'
#  '              {\n'
#  '                "topicClassValue": {\n'
#  '                  "typeName": "topicClassValue",\n'
#  '                  "typeClass": "primitive",\n'
#  '                  "multiple": false,\n'
#  '                  "value": " History of Astronomy"\n'
#  '                }\n'
#  '              }\n'
#  '            ]\n'
#  '          }\n'
#  '        ]\n'
#  '      },\n'
#  '      "socialscience": {\n'
#  '        "fields": [\n'
#  '          {\n'
#  '            "typeName": "universe",\n'
#  '            "multiple": false,\n'
#  '            "typeClass": "primitive",\n'
#  '            "value": "The Universe"\n'
#  '          }\n'
#  '        ]\n'
#  '      },\n'
#  '      "journal": {\n'
#  '        "fields": [\n'
#  '          {\n'
#  '            "typeName": "journalArticleType",\n'
#  '            "multiple": false,\n'
#  '            "typeClass": "controlledVocabulary",\n'
#  '            "value": "abstract"\n'
#  '          }\n'
#  '        ]\n'
#  '      }\n'
#  '    },\n'
#  '    "license": "CC0 1.0"\n'
#  '  }\n'
#  '}')

# %%
ds.json()
# Out:
# '{\n  "datasetVersion": {\n    "metadataBlocks": {\n      "citation": {\n        "fields": [\n          {\n            "typeName": "subject",\n            "multiple": true,\n            "typeClass": "controlledVocabulary",\n            "value": [\n              "Astronomy and Astrophysics"\n            ]\n          },\n          {\n            "typeName": "title",\n            "multiple": false,\n            "typeClass": "primitive",\n            "value": "Announcement Card number: 1"\n          },\n          {\n            "typeName": "author",\n            "multiple": true,\n            "typeClass": "compound",\n            "value": [\n              {\n                "authorName": {\n                  "typeName": "authorName",\n                  "typeClass": "primitive",\n                  "multiple": false,\n                  "value": "Mika, Katherine"\n                },\n                "authorAffiliation": {\n                  "typeName": "authorAffiliation",\n                  "typeClass": "primitive",\n                  "multiple": false,\n                  "value": "Harvard Library"\n                }\n              }\n            ]\n          },\n          {\n            "typeName": "datasetContact",\n            "multiple": true,\n            "typeClass": "compound",\n            "value": [\n              {\n                "datasetContactName": {\n                  "typeName": "datasetContactName",\n                  "typeClass": "primitive",\n                  "multiple": false,\n                  "value": "Mika, Katherine"\n                },\n                "datasetContactAffiliation": {\n                  "typeName": "datasetContactAffiliation",\n                  "typeClass": "primitive",\n                  "multiple": false,\n                  "value": "Harvard Library"\n                },\n                "datasetContactEmail": {\n                  "typeName": "datasetContactEmail",\n                  "typeClass": "primitive",\n                  "multiple": false,\n                  "value": "katherine_mika@harvard.edu"\n                }\n              }\n            ]\n          },\n          {\n            "typeName": "dsDescription",\n            "multiple": true,\n            "typeClass": "compound",\n            "value": [\n              {\n                "dsDescriptionValue": {\n                  "typeName": "dsDescriptionValue",\n                  "typeClass": "primitive",\n                  "multiple": false,\n                  "value": "Announcement Card number: 1 is a series of tables and text files associated with HCO Announcement Card number: 1. Compiled by: Harlow Shapley. Objects observed include BLATHWAYT\'S COMET."\n                }\n              }\n            ]\n          },\n          {\n            "typeName": "keyword",\n            "multiple": true,\n            "typeClass": "compound",\n            "value": [\n              {\n                "keywordValue": {\n                  "typeName": "keywordValue",\n                  "typeClass": "primitive",\n                  "multiple": false,\n                  "value": "Astronomy--Observations"\n                },\n                "keywordVocabulary": {\n                  "typeName": "keywordVocabulary",\n                  "typeClass": "primitive",\n                  "multiple": false,\n                  "value": "LCSH"\n                },\n                "keywordVocabularyURI": {\n                  "typeName": "keywordVocabularyURI",\n                  "typeClass": "primitive",\n                  "multiple": false,\n                  "value": "https://www.loc.gov/aba/cataloging/subject/"\n                }\n              },\n              {\n                "keywordValue": {\n                  "typeName": "keywordValue",\n                  "typeClass": "primitive",\n                  "multiple": false,\n                  "value": " Astronomy--Research"\n                },\n                "keywordVocabulary": {\n                  " ...

# %%
print(ds.astroType)

# %%
print(ds.validate_json())

# %%
ds = Dataset()
dataset = ds.set(first_series_metadata)
pprint.pprint(ds.json(dataset))

# %% [markdown]
# ### manually debugging the json() function in Dataset() class

# %%
__attr_import_dv_up_datasetVersion_values = [
    "license",
    "termsOfAccess",
    "fileAccessRequest",
    "protocol",
    "authority",
    "identifier",        
    "termsOfUse",
]

__attr_import_dv_up_citation_fields_values = [
    "accessToSources",
    "alternativeTitle",
    "alternativeURL",
    "characteristicOfSources",
    "dateOfDeposit",
    "dataSources",
    "depositor",
    "distributionDate",
    "kindOfData",
    "language",
    "notesText",
    "originOfSources",
    "otherReferences",
    "productionDate",
    "productionPlace",
    "relatedDatasets",
    "relatedMaterial",
    "subject",
    "subtitle",
    "title",
]

__attr_import_dv_up_citation_fields_arrays = {
    "author": [
        "authorName",
        "authorAffiliation",
        "authorIdentifierScheme",
        "authorIdentifier",
    ],
    "contributor": ["contributorType", "contributorName"],
    "dateOfCollection": ["dateOfCollectionStart", "dateOfCollectionEnd"],
    "datasetContact": [
        "datasetContactName",
        "datasetContactAffiliation",
        "datasetContactEmail",
    ],
    "distributor": [
        "distributorName",
        "distributorAffiliation",
        "distributorAbbreviation",
        "distributorURL",
        "distributorLogoURL",
    ],
    "dsDescription": ["dsDescriptionValue", "dsDescriptionDate"],
    "grantNumber": ["grantNumberAgency", "grantNumberValue"],
    "keyword": ["keywordValue", "keywordVocabulary", "keywordVocabularyURI"],
    "producer": [
        "producerName",
        "producerAffiliation",
        "producerAbbreviation",
        "producerURL",
        "producerLogoURL",
    ],
    "otherId": ["otherIdAgency", "otherIdValue"],
    "publication": [
        "publicationCitation",
        "publicationIDType",
        "publicationIDNumber",
        "publicationURL",
    ],
    "software": ["softwareName", "softwareVersion"],
    "timePeriodCovered": ["timePeriodCoveredStart", "timePeriodCoveredEnd"],
    "topicClassification": [
        "topicClassValue",
        "topicClassVocab",
        "topicClassVocabURI",
    ],
}

__attr_import_dv_up_journal_fields_values = ["journalArticleType"]

__attr_import_dv_up_journal_fields_arrays = {
    'journalVolumeIssue': ["journalVolume", "journalIssue", "journalPubDate"]
}

__attr_import_dv_up_astrophysics_fields_values = [
    "astroType",
    "astroFacility",
    "astroInstrumnet",
    "astroObject",
    "resolution.Spatial", 
    "resolution.Temporal",
    "coverage.Spectral.Bandpass",
    "coverage.Spectral.CentralWavelength",
    "coverage.Spatial",
    "coverage.Depth",
    "coverage.ObjectDensity",
    "coverage.ObjectCount",
    "coverage.SkyFraction",
    "coverage.Polarization",
    "redshiftType",
    "resolution.Redshift"
]

__attr_import_dv_up_astrophysics_fields_arrays = {
    "coverage.Spectral.Wavelength": ["coverage.Spectral.MinimumWavelength", "coverage.Spectral.MaximumWavelength"],
    "coverage.Temporal": ["coverage.Temporal.StartTime", "coverage.Temporal.StopTime"],
    "coverage.RedshiftValue": ["coverage.Redshift.MinimumValue", "coverage.Redshift.MaximumValue"]
}
__attr_dict_dv_up_type_class_primitive = (
    [
        "accessToSources",
        "alternativeTitle",
        "alternativeURL",
        "authorAffiliation",
        "authorIdentifier",
        "authorName",
        "astroType",
        "astroFacility",
        "astroInstrumnet",
        "astroObject",
        "characteristicOfSources",
        "city",
        "contributorName",
        "coverage.Spectral.Bandpass",
        "coverage.Spectral.CentralWavelength",
        "coverage.Spatial",
        "coverage.Depth",
        "coverage.ObjectDensity",
        "coverage.ObjectCount",
        "coverage.SkyFraction",
        "coverage.Polarization",
        "dateOfDeposit",
        "dataSources",
        "depositor",
        "distributionDate",
        "kindOfData",
        "notesText",
        "originOfSources",
        "otherGeographicCoverage",
        "otherReferences",
        "productionDate",
        "productionPlace",
        "publicationCitation",
        "publicationIDNumber",
        "publicationURL",
        "relatedDatasets",
        "relatedMaterial",
        "resolution.Spatial", 
        "resolution.Temporal",
        "redshiftType",
        "resolution.Redshift"
        "seriesInformation",
        "seriesName",
        "state",
        "subtitle",
        "title",
    ]
    + __attr_import_dv_up_citation_fields_arrays["dateOfCollection"]
    + __attr_import_dv_up_citation_fields_arrays["datasetContact"]
    + __attr_import_dv_up_citation_fields_arrays["distributor"]
    + __attr_import_dv_up_citation_fields_arrays["dsDescription"]
    + __attr_import_dv_up_citation_fields_arrays["grantNumber"]
    + __attr_import_dv_up_citation_fields_arrays["keyword"]
    + __attr_import_dv_up_citation_fields_arrays["producer"]
    + __attr_import_dv_up_citation_fields_arrays["otherId"]
    + __attr_import_dv_up_citation_fields_arrays["software"]
    + __attr_import_dv_up_citation_fields_arrays["timePeriodCovered"]
    + __attr_import_dv_up_citation_fields_arrays["topicClassification"]
    + __attr_import_dv_up_journal_fields_arrays["journalVolumeIssue"]
    + __attr_import_dv_up_astrophysics_fields_values
    + __attr_import_dv_up_astrophysics_fields_arrays["coverage.Temporal"]
    + __attr_import_dv_up_astrophysics_fields_arrays["coverage.Spectral.Wavelength"]
    + __attr_import_dv_up_astrophysics_fields_arrays["coverage.RedshiftValue"]
)

__attr_dict_dv_up_type_class_compound = (
    list(__attr_import_dv_up_citation_fields_arrays.keys())
    + list(__attr_import_dv_up_astrophysics_fields_arrays.keys())
)
__attr_dict_dv_up_type_class_controlled_vocabulary = [
    "authorIdentifierScheme",
    "astroType",
    "contributorType",
    "country",
    "journalArticleType",
    "language",
    "publicationIDType",
    "subject",
]

__attr_displayNames = [
    "citation_displayName",
    "geospatial_displayName",
    "socialscience_displayName",
    "journal_displayName",
    "astrophysics_displayName"
]

# %%
def __parse_field_array(data, attr_list):
    data_tmp = []

    for d in data:
        tmp_dict = {}
        for key, val in d.items():
            if key in attr_list:
                tmp_dict[key] = val['value']
            else:
                print("Key '{0}' not in attribute list".format(key))
        data_tmp.append(tmp_dict)

    return data_tmp

# %%
def __generate_field_arrays(attr, key, sub_keys):
    tmp_list = []
    for d in attr: 
        tmp_dict = {}
        for k, v in d.items():
            if k in sub_keys:
                multiple = None
                type_class = None
                if isinstance(v, list):
                    multiple = True
                else:
                    multiple = False
                if k in __attr_dict_dv_up_type_class_primitive:
                    type_class = "primitive"
                elif k in __attr_dict_dv_up_type_class_compount:
                    type_class = "compound"
                elif k in __attr_dict_dv_up_type_class_controlled_vocabulary:
                    type_class = "controlledVocabulary"
                tmp_dict[k] = {}
                tmp_dict[k]["typeName"] = k
                tmp_dict[k]["typeClass"] = type_class
                tmp_dict[k]["multiple"] = multiple
                tmp_dict[k]["value"] = v
        tmp_list.append(tmp_dict)

    return(tmp_list)

# %%
data = {}
ds = Dataset()
data_dict = ds.set(first_series_metadata)
print(ds.json(data_dict))

# %%
for attr in (
    __attr_import_dv_up_journal_fields_values
    + list(__attr_import_dv_up_journal_fields_arrays.keys())
    + ["journal_displayName"]
):
    if attr in ds:
        journal = {}
        if attr != "journal_displayName":
            journal["fields"] = []
            break

    if "journal_displayName" in ds:
        journal["displayName"] = ds["journal_displayName"]

print(journal['displayName'])

# %%
for attr in (
    __attr_import_dv_up_journal_fields_values
    + list(__attr_import_dv_up_journal_fields_arrays.keys())
    + ["journal_displayName"]
):
    if attr in data_dict:
        journal = {}
        if attr != "journal_displayName":
            journal["fields"] = []
            break



for attr in __attr_import_dv_up_journal_fields_values:
    if attr in data_dict:
        v = data_dict[attr]
        if isinstance(v, list):
            multiple = True
        else:
            multiple = False
        if attr in __attr_dict_dv_up_type_class_primitive:
            type_class = "primitive"
        elif attr in __attr_dict_dv_up_type_class_compound:
            type_class = "compound"
        elif (
            attr in __attr_dict_dv_up_type_class_controlled_vocabulary
        ):
            type_class = "controlledVocabulary"
        journal["fields"].append(
            {
                "typeName": attr,
                "multiple": multiple,
                "typeClass": type_class,
                "value": v,
            }
        )

for (
    key,
    val,
) in __attr_import_dv_up_journal_fields_arrays.items():
    if key in data_dict:
        journal["fields"].append(
            {
                "typeName": key,
                "multiple": True,
                "typeClass": "compound",
                "value": self.__generate_field_arrays(key, val),
            }
        )

print(journal)

# %%
data["datasetVersion"] = {}
data["datasetVersion"]["metadataBlocks"] = {}

for attr in (
    __attr_import_dv_up_astrophysics_fields_values
    + list(__attr_import_dv_up_astrophysics_fields_arrays.keys())
    + ["astrophysics_displayName"]
):
    if attr in data_dict:
        astrophysics = {}
        if attr != "astrophysics_displayName":
            astrophysics["fields"] = []
            break

if "astrophysics_displayName" in data_dict:
    astrophysics["displayName"] = data_dict["astrophysics_displayName"]

for attr in __attr_import_dv_up_astrophysics_fields_values:
    if attr in data_dict:
        v = data_dict[attr]
        if isinstance(v, list):
            multiple = True
        else:
            multiple = False
        if attr in __attr_dict_dv_up_type_class_primitive:
            type_class = "primitive"
        elif attr in __attr_dict_dv_up_type_class_compound:
            type_class = "compound"
        elif (
            attr in __attr_dict_dv_up_type_class_controlled_vocabulary
        ):
            type_class = "controlledVocabulary"
        astrophysics["fields"].append(
            {
                "typeName": attr,
                "multiple": multiple,
                "typeClass": type_class,
                "value": v,
            }
        )

data["datasetVersion"]["metadataBlocks"]["astrophysics"] = astrophysics
pprint.pprint(data)

# %%
json_dataset = ds.json()
pprint.pprint(json_dataset)

# %%
import json
filename = "social_data.json"

# Save the object as a JSON file
with open(filename, 'w') as json_file:
    json.dump(social_data, json_file, indent=4)

# %%
# get the base url
base_url = g_api.base_url
# get the api token
api_token = g_api.api_token
# dataverse collection url 
dataverse_alias = g_dataverse_collection
# create the headers
headers = {'X-Dataverse-key': api_token, 'Content-Type' : 'application/json'}
# create the request url
request_url = '{}/api/dataverses/{}/datasets'.format(base_url, dataverse_alias)

# %%
response = requests.post(request_url, headers=headers, data="social_data.json")
# get the status and message from the response
print(response.text)
# Out:
# {"status":"ERROR","message":"Error parsing Json: Unexpected char 115 at (line no=1, column no=1, offset=0)"}

# %%
filename = "social_data.json"

try:
    with open(filename, 'r') as file:
        content = file.read()  # Read the entire file content
        if len(content) >= 115:  # Check if the file has at least 115 characters
            char_115 = content[114]  # Index 114 corresponds to the 115th character (0-based indexing)
            print(f"The 115th character in the file is: '{char_115}'")
        else:
            print(f"The file has less than 115 characters.")
except FileNotFoundError:
    print(f"The file {filename} does not exist.")
except Exception as e:
    print(f"An error occurred: {e}")
# Out:
# The 115th character in the file is: 'n'

# %%
Dataset.validate_json(ds)

# %%
from pyDataverse.utils import read_csv_as_dicts

# %%
csv_datasets_filename = g_module_path + "/test_dataset.csv"
print(csv_datasets_filename)

# %%
ds_data = read_csv_as_dicts(csv_datasets_filename)
print(ds_data)

# %%
ds_lst = []
for ds in ds_data: 
    ds_obj = Dataset()
    ds_obj.set(ds)
    ds_lst.append(ds_obj)

# %%
g_api

# %%
dv_alias = g_dataverse_collection
dataset_id_2_pid = {}
for ds in ds_lst:
    resp = g_api.create_dataset(dv_alias, ds.json())
    dataset_id_2_pid[ds.get()["org.dataset_id"]] = resp.json()['data']['persistentId']

# %%
resp

# %%
pprint.pprint(ds.json())

# %% [markdown]
# #### 2. Test: Create the dataset

# %%
# create the test dataset
dataset_ret = curate.create_dataset(g_api, g_dataverse_collection, first_series_metadata)
print(dataset_ret.json())
# Out:
# Error: 400 - failed to create dataset Announcement Card number: 1
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[21], line 3
#       1 # create the test dataset
#       2 dataset_ret = curate.create_dataset(g_api, g_dataverse_collection, first_series_metadata)
# ----> 3 print(dataset_ret.json())
#
# AttributeError: 'dict' object has no attribute 'json'

# %%
print(dataset_ret)
# Out:
# {'status': False, 'dataset_id': -1, 'dataset_pid': ''}

# %%
import importlib
importlib.reload(curate)

# %% [markdown]
# #### 2.25. Test: using easyDataverse

# %%
import easyDataverse ### IMPORTANT ##### easyDataverse works with an earlier version of pydantic. DVUploader (python) works with a newer version.

# %% [markdown]
# #### 2.5 Test: test single file with python DVUploader
# Hard coded doi & file directory

# %%
import dvuploader as dv

files = [
    #File(filepath="/Users/katherinemika/Desktop/test/43675367_a.csv"),
    #File(directoryLabel="txt", filepath="/Users/katherinemika/Desktop/test/txt/43675367.txt"),
    *dv.add_directory("/Users/katherinemika/Desktop/curation/historic_datasets/annual_trade_reports/1925/test_batch/"),
]

dvuploader = DVUploader(files=files)
dvuploader.upload(
    api_token=g_dataverse_api_key,
    dataverse_url="https://dataverse.harvard.edu",
    persistent_id="doi:10.7910/DVN/WDBXNN",
    n_parallel_uploads= 2
)

# %% [markdown]
# #### 3. Test: Direct upload the datafiles associated with the dataset (series name)

# %%
# upload the series dataset datafiles 
#test_datafiles_path = "/Users/katherinemika/Desktop/test/"
pid = dataset_ret.get('dataset_pid')
ret = curate.direct_upload_datafiles(g_api, g_dataverse_installation_url, pid, g_datafiles_path, datafile_metadata_df)

# %% [markdown]
# #### 4. Test: Examine a directory to make certain all files exist before attempting an upload of datafiles

# %%
# test to see if all files are there and report the ones that aren't

import os
errors = {}
for row in g_dataverse_inventory_df.iterrows():
    filename = row[1].get('filename_osn')
    filepath = g_datafiles_path + '/' + filename
    if (os.path.exists(filepath)):
        errors[filepath] = True
    else:
        print('File not found: {}'.format(filepath))
        errors[filepath] = False

# %% [markdown]
# #### Test and build functions for adding files to datasets via python dvuploader

# %% [markdown]
# psuedo code:
#
# 1. list of files to add to each dataset
# 2. loop dvuploader.upload module for each dataset

# %%
import dvuploader as dv

# %%
def python_dvuploader(api, dataverse_url, dataset_pid, data_directory, metadata_df):
    """
    Upload Open Metadata datafiles to dataverse repository using direct upload method

    Parameters
    ----------
    api : pyDataverse api
    dataverse_url : str
        Dataverse installation url (e.g., https://demo.dataverse.org)
    dataset_pid : str
        Persistent identifier for the dataset (its DOI, takes form: doi:xxxxx)
    data_directory : str
        Directory where datafiles are kept
    metadata_df : DataFrame
        DataFrame containing metadata about datafiles to upload

    Return
    ------
    dict
        {upload: bool, errors: list, finalize: bool}
    """

    #validate params
    if ((not api) or 
        (not dataverse_url) or
        (not dataset_pid) or
        (not data_directory) or
        (metadata_df.empty==True)):
        return False

    #error msg
    errors = []

    json_data = []
    cats = None

    #add each file in metadata_df to files list for dvuploader
    
    files = []
    
    for row in metadata_df.iterrows():
        file = row[1].get('filename_osn')
        filepath = g_datafiles_path + "/" + file
        file_name = row[1].get('custom_name')
        desc = row[1].get('description')
        mime_type = row[1].get('mimetype')

        #format tags
        tags = row[1].get('tags')
        tags_lst = eval(tags)
        
        files.append(dv.File(filepath = filepath,
                             file_name = file_name,
                             description = desc,
                             mimeType = mime_type,
                             categories = tags_lst
                            )
                    )
        
        print('Uploading: {}/{} - {} {}'.format(data_directory, filepath, desc, mimeType))

        
    key = api.api_token
    dvuploader = dv.DVUploader(files=files)
        
    dvuploader.upload(
        api_token = key,
        dataverse_url = dataverse_url,
        persistent_id = dataset_pid,
        n_parallel_uploads= 2 #however many your installation can handle
    )

# %%
pid = dataset_ret.get('dataset_pid')
ret = python_dvuploader(g_api, g_dataverse_installation_url, pid, g_datafiles_path, datafile_metadata_df)

# %% [markdown]
# #### 5. Test: Delete all the datasets in the collection and start again
# - WARNING: This is a permanent operation. Be very certain you want to perform this operation!

# %%
# delete all the datasets
# ARE YOU SURE ABOUT THIS? if so, uncomment the next line and execute
ret = curate.delete_datasets(g_api, g_dataverse_collection)

# %% [markdown]
# **End document.**
