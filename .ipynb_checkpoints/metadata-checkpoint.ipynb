# %% [markdown]
# # PART I: TITLE CREATION

# %%
import pandas as pd
import os
import numpy as np
import re
from collections import Counter
import spacy
from spacy.language import Language
from spacy_language_detection import LanguageDetector

# %%
#set globals

#list of all ports in vol
port_names = [
    "Amoy",
    "Canton",
    "Chefoo",
    "Chinkiang",
    "Foochow",
    "Hankow",
    "Kiukiang",
    "Newchang",
    "Ningpo", 
    "Shanghai",
    "Shanghae"
    "Yang-Tsze",
    "Swatow",
    "Tamsui",
    "Tientsin"
]

#list of years in vol
g_all_years = [
    "1860",
    "1861",
    "1862",
    "1863",
    "1864",
    "1865",
    "1866"
]

#source path
source_path = '/Users/katherinemika/Desktop/curation/historic_datasets/returns_trade_ports/'

# %% [markdown]
# #### Create local directory for combined csv and txt files
#
# `cp ".../annual_trade_reports/csv/*" ".../annual_trade_reports/csv_and_txt"`
# `cp ".../annual_trade_reports/txt/*" ".../annual_trade_reports/csv_and_txt"`

# %%
def title_maker(year):
    
    folder_path = source_path + str(year) + '/csv_and_txt'
    
    files_list = os.listdir(folder_path)
    
    #dataframe with names of all the files in the folder 
    df = pd.DataFrame(files_list,columns=['file_name'])
    
    df = df.sort_values(by="file_name",ascending=True).reset_index().drop(columns=['index'])
    
    #get file type (csv or txt)
    df["file_type"] = df["file_name"].str[-3:]
    
    df["file_name"] = df["file_name"].str[:-4]
    
    df["title_port"] = np.nan
    
    df['title_port'] = df['title_port'].astype(object)

    df["title_table_type"] = np.nan
    
    df['title_table_type'] = df['title_table_type'].astype(object)
    
    #list that will contain the page numbers of all content pages
    content_pages = []
    
    #loops through each txt file in the folder
    for index, row in df.iterrows():
        
        if row['file_type'] == 'txt':
            
            file_path = source_path + str(year) + '/txt/' + str(df.loc[index]['file_name'])+'.txt'
            file = open(file_path, 'r')
            Lines = file.readlines()
            
            #removes trailing characters from each line in the file
            lines_list = [line.strip('\n').strip('.').title() for line in Lines]
            
            #removes roman numerical characters from the beginning of all lines (this is for the port name titles)  
            combinations_to_remove = [r"I\.?[-—─-]", r"Ii\.?[-—─-]",r"Iii\.?[-—─-]",r"Iv\.?[-—─-]",r"V\.?[-—─-]",r"Vi\.?[-—─-]",r"Vii\.?[-—─-]",r"Viii\.?[-—─-]",r"Ix\.?[-—─-]"]
            pattern = '|'.join(combinations_to_remove)
            lines_list = [re.sub(pattern, "", line) for line in lines_list]
            
            #convert lists to sets
            file_set = set(lines_list)
            all_ports = set(port_names)
            all_years = set(g_all_years)

            #isolate string contents for ports
            extracted_ports = set()
            for l in file_set:
                for port in all_ports:
                    if port in l:
                        extracted_ports.add(port)
            
            #check whether any port names occur in the file
            common_elements_title_port = extracted_ports.intersection(all_ports)

            # Check if exactly one port name appears
            if len(common_elements_title_port) == 1:
                #if yes, this file is the cover/starting page for the port whose name appears  
                df.at[index, 'title_port'] = list(common_elements_title_port)[0]

                #isolate string contents for years
            extracted_yrs = set()
            for l in file_set:
                for yr in all_years:
                    if yr in l:
                        extracted_yrs.add(yr)    
        
        #check if any table type titles occur in the file 
            common_elements_title_year = extracted_yrs.intersection(all_years)
            
            #check if exactly one year appears in this file 
            if len(common_elements_title_year) == 1:
                #if yes, this is the cover/starting page for that year type
                df.at[index, 'title_year'] = list(common_elements_title_year)[0]
    
    #forward fills the title column, ie. every page takes the value of the last valid/occuring title port name  
    #df['title_port'] = df['title_port'].fillna(method='ffill')
    df['title_port'] = df['title_port'].ffill()
    
    if df.loc[0, 'title_port'] is np.nan:
        df.loc[0, 'title_port'] = df.loc[1, 'title_port']
    
    #within the same port name, every page takes the value of the last valid/occuring table type   
    #df["new_table_type"] = df.groupby('title_port')['title_table_type'].fillna(method="ffill")
    df["report_years"] = df.groupby('title_port')['title_year'].ffill().infer_objects(copy=False)
    
    #marks all the content pages
    #df.loc[df['file_name'].isin(content_pages), 'report_years'] = "Contents"
    
    df = df.drop(columns={"title_year"})
    df = df.rename(columns={"report_years":"title_year"})
    
    df["year"] = year
    df["file_path"] = df["file_name"] +"."+ df["file_type"]
    
    #files that come before the table types are categorized as "Notes"   
    df = df.fillna("Notes")
    
    df["title"] = df["title_port"]+ "-" +df["title_year"]
    
    return df[["title_port","title_year","year","file_path","title"]]

# %%
df_returns_trade_ports = title_maker(1866)

# %%
df_returns_trade_ports
# Out:
#      title_port title_year  year        file_path          title
# 0         Notes      Notes  1866        .DS_S.ore    Notes-Notes
# 1          Amoy       1863  1866     38484874.txt      Amoy-1863
# 2          Amoy       1863  1866     38484875.txt      Amoy-1863
# 3          Amoy       1863  1866     38484876.txt      Amoy-1863
# 4          Amoy       1863  1866     38484877.txt      Amoy-1863
# ...         ...        ...   ...              ...            ...
# 1891   Tientsin       1865  1866     38486165.csv  Tientsin-1865
# 1892   Tientsin       1865  1866     38486165.txt  Tientsin-1865
# 1893   Tientsin       1865  1866     38486166.txt  Tientsin-1865
# 1894   Tientsin       1865  1866  38486166_a .csv  Tientsin-1865
# 1895   Tientsin       1865  1866  38486166_b .csv  Tientsin-1865
#
# [1896 rows x 5 columns]

# %%
df_returns_trade_ports.to_csv(source_path + str(1866) + "/data_frame.csv", index=False)

# %% [markdown]
# # PART II: NLP ENTITIES CREATION

# %% [markdown]
# ### II(a) Create entities for all csv files

# %%
# Define the language detector factory function
def get_lang_detector(nlp, name):
    return LanguageDetector(seed=42)

# Load the spaCy model and register the language detector factory if not already registered
nlp = spacy.load('en_core_web_sm')
if 'language_detector' not in nlp.pipe_names:
    Language.factory("language_detector", func=get_lang_detector)
    nlp.add_pipe('language_detector', last=True)

@Language.component("filter_non_english_entities")
def filter_non_english_entities(doc):
    filtered_ents = []
    for ent in doc.ents:
        if all(token.is_alpha for token in ent):
            filtered_ents.append(ent)
    doc.ents = filtered_ents
    return doc

# Add the custom filter component to remove non-English entities
if 'filter_non_english_entities' not in nlp.pipe_names:
    nlp.add_pipe("filter_non_english_entities", last=True)

# %%
def nlp_entities_maker_csv(year):
    folder_path_csv = source_path + str(year) + '/csv'
    files_list = os.listdir(folder_path_csv)
    csv_files_df = pd.DataFrame(files_list, columns=['file_name'])
    csv_files_df['nlp_entities'] = '[]'

    for index, row in csv_files_df.iterrows():
        file_path = os.path.join(folder_path_csv, row["file_name"])
        df = pd.read_csv(file_path)

        # Load the NER model
        nlp = spacy.load('en_core_web_sm')

        # Set the max_length attribute
        nlp.max_length = 2000000
        
        if 'DESCRIPTION OF GOODS.' in df.columns:
            df["DESCRIPTION OF GOODS."] = df["DESCRIPTION OF GOODS."].fillna("").astype(str)
            combined_text = ' '.join(df["DESCRIPTION OF GOODS."].tolist())
        else:
            combined_text = ' '.join(df.astype(str).apply(lambda x: ' '.join(x), axis=1))
            column_names = ' '.join(df.columns)
            combined_text += ' ' + column_names

        # Check if 'language_detector' factory is already registered
        if 'language_detector' not in nlp.pipe_names:
            Language.factory("language_detector", func=get_lang_detector)
            nlp.add_pipe('language_detector', last=True)

        doc = nlp(combined_text)

        entities = [ent.text for ent in doc.ents if ent.label_ == 'WORK_OF_ART' or (not any(char.isdigit() for char in ent.text) and 'nan' not in ent.text.lower())]
        entity_counts = Counter(entities)
        most_common_entities = entity_counts.most_common(7)
        
        csv_files_df.at[index, 'nlp_entities'] = most_common_entities
    
    csv_files_df = csv_files_df.rename(columns={"file_name": "file_path"})
    return csv_files_df

# %% [markdown]
# ### II(b) Create entities for all txt files

# %%
#clean all txt files first
def clean_txt_files(year):
    folder_path_txt = source_path + str(year) + '/txt'
    files_list = os.listdir(folder_path_txt)
    txt_files_df = pd.DataFrame(files_list,columns=['file_name'])
    
    for index, row in txt_files_df.iterrows():
        file_path = folder_path_txt + '/' + str(row['file_name'])
        with open(file_path, 'rb') as file:
            dirty_txt = file.read()
    
        clean_data = dirty_txt.decode('utf-8', 'ignore')

        # Write the clean data to the output file in text mode
        with open(file_path, 'w', encoding='utf-8') as file:
            file.write(clean_data)

# %%
clean_txt_files(1866)

# %%
def nlp_entities_maker_txt(year):
    
    # Load the NER model
    nlp = spacy.load('en_core_web_sm')
    
    # Check if 'language_detector' factory is already registered
    if 'language_detector' not in nlp.pipe_names:
        Language.factory("language_detector", func=get_lang_detector)
        nlp.add_pipe('language_detector', last=True)

    # Add the custom filter component to remove non-English entities
    nlp.add_pipe("filter_non_english_entities", last=True)

    folder_path_txt = source_path + str(year) + '/txt'
    files_list = os.listdir(folder_path_txt)
    txt_files_df = pd.DataFrame(files_list, columns=['file_name'])
    txt_files_df['nlp_entities'] = '[]'

    for index, row in txt_files_df.iterrows():
        file_path = folder_path_txt + '/' + str(row['file_name'])
        
        # Read the content of the text file
        with open(file_path, 'r', encoding='utf-8') as file:
            text = file.read()

        doc = nlp(text)

        # Excludes entities with digits and entities containing 'NaN'
        entities = [ent.text for ent in doc.ents if not any(char.isdigit() for char in ent.text) and 'nan' not in ent.text.lower()]

        # Counts the occurrences of each entity
        entity_counts = Counter(entities)

        # The 7 most common entities
        most_common_entities = entity_counts.most_common(7)

        txt_files_df.at[index, 'nlp_entities'] = most_common_entities
        txt_files_df = txt_files_df.rename(columns={"file_name": "file_path"})
    
    return txt_files_df

# %% [markdown]
# # FINAL FUNCTION

# %%
def spreadsheet_maker(year):
    try:
        csv_files_df = nlp_entities_maker_csv(year)
        txt_files_df = nlp_entities_maker_txt(year)
        nlp_entities_year = pd.concat([txt_files_df, csv_files_df], axis=0)
        df_titles_year = title_maker(year)
        all_cols_year = pd.merge(df_titles_year, nlp_entities_year, on="file_path", how="left")
        return all_cols_year
    except Exception as e:
        print(f"Error in spreadsheet_maker: {e}")
        return None

# %%
metadata = spreadsheet_maker(1866)
metadata.to_csv(source_path + str(1866) + "/returns_trades_ports_metadata.csv", index=False)

# %% [markdown]
# ## Testing & troubleshooting errors

# %% [markdown]
# `csv` files must be properly formatted for this script to work. If the encoding is funny, or there's column of values that are not aligned correctly, the spreadsheet maker will fail. It usually works to test whether a file can be read into a dataframe. If it can't then you have to manually inspect it, dpending on the error message, and go from there.

# %%
folder_path_csv = source_path + str(1866) + '/csv'
files_list = os.listdir(folder_path_csv)
csv_files_df = pd.DataFrame(files_list, columns=['file_name'])

# %%
csv_files_df
# Out:
#                   file_name
# 0            38485819_c.csv
# 1    38486004_1131-1133.csv
# 2      38485564_691-694.csv
# 3            38485569_a.csv
# 4      38485671_798-803.csv
# ..                      ...
# 598  38486061_1188-1189.csv
# 599  38485976_1103-1104.csv
# 600          38485485_a.csv
# 601            38485821.csv
# 602          38485373_b.csv
#
# [603 rows x 1 columns]

# %%
for index, row in csv_files_df.iterrows():
    #print(index, row)
    print(folder_path_csv + '/' + str(row['file_name']))
    df = pd.read_csv(folder_path_csv + '/' + str(row["file_name"]))
    print(df)
# Out:
# /Users/katherinemika/Desktop/curation/historic_datasets/returns_trade_ports/1866/csv/38485819_c.csv
#                                           Unnamed: 0     MALWA. Unnamed: 2  \
# 0                                           IMPORTS,    Chests.    Weight.
# 1    Imported and stored on board Receiving Vessels,  19,513.50  19,513.50
# 2  Imported and transhipped for re-exportation wi...        391     391.00
# 3                      Imported direct to the Shore,        444     444.00
# 4                                                NaN  20,348.50  20,348.50
# 5  Landed from Receiving Vessels and intended chi...      9,351   9,350.75
# 6                                        RE-EXPORTS,        NaN        NaN
# 7  Transhipped from Receiving Vessels for Yangtsz...      5,951   5,950.20
# 8  Transhipded from Receiving Vessels for Coast P...      6,320   6,319.25
# 9                                                NaN     12,271  12,269.45
#
#     PATNA. Unnamed: 4 BENARES. Unnamed: 6 PERSIAN. Unnamed: 8  TURKEY.  \
# 0  Chests.    Weight.  Chests.    Weight.  Chests.    Weight.  Chests.
# 1    7,183   8,619.60    1,003   1,203.60       25      25.00       17
# 2        7       8.40        4       4.80       10      10.00      NaN
# 3      207     248.40        3       3.60       37      37.00      NaN
# 4    7,397   8,876.40    1,010   1,212.00       72      72.00       17
# 5    7,112   8,533.26      911   1,093.20        1       1.00      NaN
# 6      NaN        NaN      NaN        NaN      NaN        NaN      NaN
# 7       96     115.20        5       6.00       27      27.00      NaN
# 8   337.50     405.00       30      36.00       40      40.00       17
# 9   433.50     520.20       35      42.00       67      67.00       17
#
#   Unnamed: 10
# 0     Weight.
# 1       13.00
# 2         NaN
# 3         NaN
# 4       13.50
# 5         NaN
# 6         NaN
# 7         NaN
# 8       13.50
# 9       13.50
# /Users/katherinemika/Desktop/curation/historic_datasets/returns_trade_ports/1866/csv/38486004_1131-1133.csv
#     DESCRIPTION OF GOODS. CLASSIFIER OF QUANTITY.  HONGKONG.  Unnamed: 3  \
# 0                     NaN                     NaN  Quantity.         NaN
# 1                Chintez,                  Pieces        315         NaN
# 2          Cottons, Dyed,                       „      2,695         NaN
# 3               Dimities,                       „        100         NaN
# 4       Drills, American,                       „        794         NaN
# ..                    ...                     ...        ...         ...
# 116            „ Kranjee,                  Pieces        NaN         NaN
# 117                „ Red,                  Peculs         35         NaN
# 118              „ Sapan,                       „         60         NaN
# 119             „ Sandal,                       „         15         NaN
# 120                Total.                 Dollars        NaN         NaN
#
#     Unnamed: 4 BRITISH POSSESSIONS IN THE STRAITS.  Unnamed: 6 Unnamed: 7  \
# 0       Value.                           Quantity.         NaN     Value.
# 1        1,102                                 NaN         NaN        NaN
# 2        8,355                                   5         NaN         15
# 3          150                                 NaN         NaN        NaN
# 4        3,970                                  20         NaN        100
# ..         ...                                 ...         ...        ...
# 116        NaN                                 120         NaN         96
# 117        105                                 325         NaN        975
# 118        240                               2,050         NaN      8,200
# 119        225                                  44         NaN        660
# 120  3,754,768                                 NaN         NaN    117,798
#
#        SAIGON.  Unnamed: 9 Unnamed: 10     TOTAL.  Unnamed: 12 Unnamed: 13
# 0    Quantity.         NaN      Value.  Quantity.          NaN      Value.
# 1          NaN         NaN         NaN        315          NaN       1,102
# 2          NaN         NaN         NaN      2,700          NaN       8,370
# 3          NaN         NaN         NaN        100          NaN         150
# 4          NaN         NaN         NaN        814          NaN       4,070
# ..         ...         ...         ...        ...          ...         ...
# 116        NaN         NaN         NaN        120          NaN          96
# 117        NaN         NaN         NaN        360          NaN       1,080
# 118      1,878         NaN       7,512      3,988          NaN      15,952
# 119        NaN         NaN         NaN         59          NaN         885
# 120        NaN         NaN      40,609        NaN          NaN   3,913,175
#
# [121 rows x 14 columns]
# /Users/katherinemika/Desktop/curation/historic_datasets/returns_trade_ports/1866/csv/38485564_691-694.csv
#                DESCRIPTION OF GOODS.    IN 260 BRITISH VESSELS. Unnamed: 2  \
# 0                                NaN  Aggregate Tonnage 34,432.        NaN
# 1                                NaN                    Pieces.    Peculs.
# 2                         Agar Agar,                        NaN          1
# 3                           Almonds,                        NaN         40
# 4                       Alum, White,                        NaN      3,965
# ..                               ...                        ...        ...
# 196                          „ Laka,                        NaN        119
# 197                        „ Sandal,                        NaN        NaN
# 198                            Wool,                        NaN         78
# 199  Woollen and Cotton Piece Goods,                        NaN        NaN
# 200                              NaN                        NaN        NaN
#
#     Unnamed: 3     IN 51 FRENCH VESSELS. Unnamed: 5 Unnamed: 6  \
# 0          NaN  Aggregate Tonnage 3,183.        NaN        NaN
# 1         Cts.                   Pieces.    Peculs.       Cts.
# 2           38                       NaN        NaN        NaN
# 3           83                       NaN          4         23
# 4           59                       NaN         28         50
# ..         ...                       ...        ...        ...
# 196         86                       NaN        NaN        NaN
# 197        NaN                       NaN        NaN        NaN
# 198         75                       NaN        NaN        NaN
# 199        NaN                       NaN        NaN        NaN
# 200        NaN                       NaN        NaN        NaN
#
#       IN 137 AMERICAN VESSELS. Unnamed: 8 Unnamed: 9  \
# 0    Aggregate Tonnage 10,415.        NaN        NaN
# 1                      Pieces.    Peculs.       Cts.
# 2                          NaN        NaN        NaN
# 3                          NaN         58         13
# 4                          NaN        262         00
# ..                         ...        ...        ...
# 196                        NaN        NaN        NaN
# 197                        NaN          2         30
# 198                        NaN        NaN        NaN
# 199                        NaN        NaN        NaN
# 200                        NaN        NaN        NaN
#
#          IN 53 SUNDRY VESSELS. Unnamed: 11 Unnamed: 12  \
# 0    Aggregate Tonnage 11,195.         NaN         NaN
# 1                      Pieces.     Peculs.        Cts.
# 2                          NaN         NaN         NaN
# 3                          NaN          36          04
# 4                          NaN       6,267          00
# ..                         ...         ...         ...
# 196                        NaN         NaN         NaN
# 197                        NaN         NaN         NaN
# 198                        NaN          93          40
# 199                         70         NaN         NaN
# 200                        NaN         NaN         NaN
#
#           IN 38 NINGPO BOATS. Unnamed: 14 Unnamed: 15  \
# 0    Aggregate Tonnage 1,818.         NaN         NaN
# 1                     Pieces.     Peculs.        Cts.
# 2                         NaN         NaN         NaN
# 3                         NaN           1          62
# 4                         NaN         662          00
# ..                        ...         ...         ...
# 196                       NaN         NaN         NaN
# 197                       NaN         NaN         NaN
# 198                       NaN         NaN         NaN
# 199                       NaN         NaN         NaN
# 200                       NaN         NaN         NaN
#
#          TOTAL IN 539 VESSELS. Unnamed: 17 Unnamed: 18 ESTIMATED VALUE.
# 0    Aggregate Tonnage 61,043.         NaN         NaN              NaN
# 1                      Pieces.     Peculs.        Cts.      Mex. Dolls.
# 2                          NaN           1          38                8
# 3                          NaN         140          85            2,535
# 4                          NaN      11,185          09           16,778
# ..                         ...         ...         ...              ...
# 196                        NaN         119          86              479
# 197                        NaN           2          30               27
# 198                        NaN         172          15            1,291
# 199                         70         NaN         NaN              210
# 200                        NaN         NaN         NaN        2,023,914
#
# [201 rows x 20 columns]
# /Users/katherinemika/Desktop/curation/historic_datasets/returns_trade_ports/1866/csv/38485569_a.csv
#                DESTINATION.  CONGOU. Unnamed: 2 SOUCHONG. Unnamed: 4  OOLONG.  \
# 0                       NaN  Peculs.       Cts.   Peculs.       Cts.  Peculs.
# 1    Great Britain, direct,      NaN        NaN       NaN        NaN      NaN
# 2            United States,      NaN        NaN       NaN        NaN      NaN
# 3  Hongkong and Cost Ports,      NaN        NaN       NaN        NaN      NaN
# 4                Australia,      NaN        NaN       NaN        NaN      NaN
# 5             Total Peculs,      NaN        NaN       NaN        NaN      NaN
#
#   Unnamed: 6 FLOWERY PEKOE.  Unnamed: 8 TOTAL BLACK.  ... TWANKAY.  \
# 0       Cts.         Peculs.       Cts.      Peculs.  ...  Peculs.
# 1        NaN             NaN        NaN          NaN  ...      NaN
# 2        NaN             NaN        NaN          NaN  ...      NaN
# 3        NaN             NaN        NaN          NaN  ...      387
# 4        NaN             NaN        NaN          NaN  ...      NaN
# 5        NaN             NaN        NaN          NaN  ...      387
#
#   Unnamed: 18 IMPERIAL. Unnamed: 20 GUNPOWDER. Unnamed: 22 TOTAL GREEN.  \
# 0        Cts.   Peculs.        Cts.    Peculs.        Cts.      Peculs.
# 1         NaN       NaN         NaN        NaN         NaN          NaN
# 2         NaN       NaN         NaN        NaN         NaN          NaN
# 3          22       782          13      1,017          03        5,177
# 4         NaN       NaN         NaN        NaN         NaN          NaN
# 5          22       782          13      1,017          03        5,177
#
#   Unnamed: 24 TEA LEAF. Unnamed: 26
# 0        Cts.   Peculs.        Cts.
# 1         NaN       NaN         NaN
# 2         NaN       NaN         NaN
# 3          82     9,370          79
# 4         NaN       NaN         NaN
# 5          82     9,370          79
#
# [6 rows x 27 columns]
# /Users/katherinemika/Desktop/curation/historic_datasets/returns_trade_ports/1866/csv/38485671_798-803.csv
#       DESCRIPTION OF GOODS. IN 238 BRITISH VESSELS.*  Unnamed: 2 Unnamed: 3  \
# 0                       NaN         Aggregate 73,297.        NaN        NaN
# 1                       NaN                   Pieces.    Peculs.       Cts.
# 2    Plain Shirtings, Grey,                   450,853        NaN        NaN
# 3                 „ „ Dyed,                     8,496        NaN        NaN
# 4                „ „ White,                   73,6806        NaN        NaN
# ..                      ...                       ...        ...        ...
# 298              „ Seented,                        40          2         40
# 299                „ Knees,                       NaN        NaN        NaN
# 300              Wood-Ware,                       NaN        NaN        NaN
# 301                   Wool,                       NaN         38          0
# 302                     NaN                       NaN        NaN        NaN
#
#     Unnamed: 4 IN 103 AMERICAN VESSELS.†  Unnamed: 6 Unnamed: 7 Unnamed: 8  \
# 0          NaN  Aggregate Tonnage 23,371.        NaN        NaN        NaN
# 1        Pkgs.                    Pieces.    Peculs.       Cts.      Pkgs.
# 2          NaN                    153,856        NaN        NaN        NaN
# 3          NaN                      6,000        NaN        NaN        NaN
# 4          NaN                     40,271        NaN        NaN        NaN
# ..         ...                        ...        ...        ...        ...
# 298        NaN                        NaN          1         22        NaN
# 299        NaN                        NaN        NaN        NaN        NaN
# 300        NaN                        NaN        NaN        NaN        NaN
# 301        NaN                        NaN        NaN        NaN        NaN
# 302        NaN                        NaN        NaN        NaN        NaN
#
#       IN 203 SUNDRY VESSELS.‡  Unnamed: 10 Unnamed: 11 Unnamed: 12  \
# 0    Aggregate Tonnage 26,581.         NaN         NaN         NaN
# 1                      Pieces.     Peculs.        Cts.       Pkgs.
# 2                      247,072         NaN         NaN         NaN
# 3                        2,748         NaN         NaN         NaN
# 4                       92,161         NaN         NaN         NaN
# ..                         ...         ...         ...         ...
# 298                        NaN          13          60         NaN
# 299                        NaN         NaN         NaN         NaN
# 300                        NaN          12          84         NaN
# 301                        NaN         NaN         NaN         NaN
# 302                        NaN         NaN         NaN         NaN
#
#         TOTAL IN 544 VESSELS.§  Unnamed: 14 Unnamed: 15 Unnamed: 16  \
# 0    Aggregate Tonnage 123,249.         NaN         NaN         NaN
# 1                       Pieces.     Peculs.        Cts.       Pkgs.
# 2                       851,781         NaN         NaN         NaN
# 3                        17,244         NaN         NaN         NaN
# 4                       206,238         NaN         NaN         NaN
# ..                          ...         ...         ...         ...
# 298                         NaN          17          22         NaN
# 299                          40         NaN         NaN         NaN
# 300                         NaN          12          84         NaN
# 301                         NaN          38          00         NaN
# 302                         NaN         NaN         NaN         NaN
#
#     ESTIMATED VALUE.
# 0                NaN
# 1             Taels.
# 2       1,533,205.80
# 3          43,110.00
# 4         391,852.20
# ..               ...
# 298           206.60
# 299             4.00
# 300           256.80
# 301           285.00
# 302    *8,929,514.90
#
# [303 rows x 18 columns]
# /Users/katherinemika/Desktop/curation/historic_datasets/returns_trade_ports/1866/csv/38485862_a .csv
#                     FLAGS. ENTERED INWARDS. Unnamed: 2   Unnamed: 3  \
# 0                      NaN      WITH CARGO.        NaN  IN BALLAST.
# 1                      NaN              No.      Tons.          No.
# 2                 British,              935    465,736           76
# 3                American,              486    271,611           30
# 4                  French,               40     20,644            1
# 5                 Russian,                6      2,773            1
# 6                Prussian,               16      3,729            4
# 7                  Danish,                9      2,356            2
# 8   Norweigan and Swedish,                5      1,213          NaN
# 9                   Dutch,               15      4,689            1
# 10                Hamburg,               56     20,944            8
# 11                 Bremen,               22      7,321            3
# 12                Hanover,                3        531          NaN
# 13            Mecklenburg,                3        506          NaN
# 14              Oldenburg,                2        296          NaN
# 15                Spanish,                6      1,528          NaN
# 16             Australian,                2        468          NaN
# 17                Italian,                2        808          NaN
# 18                Siamese,                6      2,818          NaN
# 19                  Total,            1,614    807,971          126
#
#    Unnamed: 4 Unnamed: 5 Unnamed: 6                FLAGS..1 CLEARED OUTWARDS.  \
# 0         NaN     TOTAL.        NaN                     NaN       WITH CARGO.
# 1       Tons.        No.      Tons.                     NaN               No.
# 2      22,222      1,011    487,958                British,               858
# 3      11,321        516    282,932               American,               466
# 4          66         41     20,710                 French,                37
# 5         142          7      2,915                Russian,                 4
# 6       1,237         20      4,966               Prussian,                16
# 7         265         11      2,621                 Danish,                 6
# 8         NaN          5      1,213  Norweigan and Swedish,                 6
# 9         450         16      5,139                  Dutch,                15
# 10      3,150         64     24,094                Hamburg,                53
# 11      1,632         25      8,953                 Bremen,                22
# 12        NaN          3        531                Hanover,                 7
# 13        NaN          3        506            Mecklenburg,                 3
# 14        NaN          2        296              Oldenburg,                 2
# 15        NaN          6      1,528                Spanish,                 7
# 16        NaN          2        468             Australian,                 4
# 17        NaN          2        808                Italian,                 3
# 18        NaN          6      2,818                Siamese,                 6
# 19     40,485      1,740    848,456                  Total,             1,515
#
#    Unnamed: 9  Unnamed: 10 Unnamed: 11 Unnamed: 12 Unnamed: 13
# 0         NaN  IN BALLAST.         NaN      TOTAL.         NaN
# 1       Tons.          No.       Tons.         No.       Tons.
# 2     418,353          208     100,055       1,066     518,408
# 3     268,497           46      20,327         512     288,824
# 4      18,100           11       4,209          48      22,309
# 5       1,961            1         709           5       2,670
# 6       4,228            7       1,441          23       5,669
# 7       1,611            4       1,085          10       2,696
# 8       1,364            2         505           8       1,869
# 9       4,647            4       1,557          19       6,204
# 10     18,155            9       3,183          62      21,338
# 11      7,990            2       1,529          24       8,519
# 12      1,261          NaN         NaN           7       1,261
# 13        498          NaN         NaN           3         498
# 14        298          NaN         NaN           2         298
# 15      1,835          NaN         NaN           7       1,835
# 16      1,216            1         519           5       1,735
# 17      1,157          NaN         NaN           3       1,157
# 18      2,457          NaN         NaN           6       2,457
# 19    753,628          295     134,119       1,810     887,747
# /Users/katherinemika/Desktop/curation/historic_datasets/returns_trade_ports/1866/csv/38485151.csv
#       DESCRIPTION OF GOODS. IN 11 BRITISH VESSELS. Aggregate Tonnage 3,710.  \
# 0                       NaN                                         Pieces.
# 1          Aniseed, Broken,                                             NaN
# 2                   „ Star,                                             NaN
# 3                 Betelnut,                                             NaN
# 4      Bicho de Mar, Black,                                             NaN
# 5              Bombazettes,                                             NaN
# 6      Cardamoms, Inferior,                                             NaN
# 7               China Root,                                             NaN
# 8           „ Ware, Coarse,                                             NaN
# 9                 Chintzes,                                           1,000
# 10           Copper, Japan,                                             NaN
# 11  Feathers, Kingfisher's,                                           4,200
# 12                Galangal,                                             NaN
# 13          Lacquered Ware,                                             NaN
# 14               Long Ells,                                               3
# 15         Medicine, Pills,                                             NaN
# 16                   Myrrh,                                             NaN
# 17                Nankeens,                                             NaN
# 18            Opium, Malwa,                                             NaN
# 19                 „ Patna,                                             NaN
# 20           „ Prepared,                                                NaN
# 21      Paper, 2nd quality,                                             NaN
# 22         Seeds, Lucraban,                                             NaN
# 23  Spanish Stripes, Changs                                              48
# 24                Tin Foil,                                             NaN
# 25                      NaN                                             NaN
#
#    Unnamed: 2 Unnamed: 3 Unnamed: 4  \
# 0     Peculs.       Cts.      Pkgs.
# 1          25         20        NaN
# 2          10         80        NaN
# 3          60         00        NaN
# 4         NaN        NaN        NaN
# 5         NaN        NaN        NaN
# 6           2         43        NaN
# 7          11         27        NaN
# 8         331         15        NaN
# 9         NaN        NaN        NaN
# 10         98         70        NaN
# 11        NaN        NaN        NaN
# 12        NaN        NaN        NaN
# 13          1         00        NaN
# 14        NaN        NaN        NaN
# 15        NaN         12        NaN
# 16        NaN        NaN        NaN
# 17        NaN        NaN        NaN
# 18        NaN        NaN        NaN
# 19        NaN        NaN        NaN
# 20        NaN        NaN        NaN
# 21        NaN        NaN        NaN
# 22        144         00        NaN
# 23        NaN        NaN        NaN
# 24        NaN        NaN        NaN
# 25        NaN        NaN        NaN
#
#    IN 1 AMERICAN VESSELS.\nAggregate Tonnage 455. Unnamed: 6 Unnamed: 7  \
# 0                                         Pieces.    Peculs.       Cts.
# 1                                             NaN        NaN        NaN
# 2                                             NaN        NaN        NaN
# 3                                             NaN        NaN        NaN
# 4                                             NaN        NaN        NaN
# 5                                             NaN        NaN        NaN
# 6                                             NaN        NaN        NaN
# 7                                             NaN        NaN        NaN
# 8                                             NaN        NaN        NaN
# 9                                             NaN        NaN        NaN
# 10                                            NaN        NaN        NaN
# 11                                            NaN        NaN        NaN
# 12                                            NaN        NaN        NaN
# 13                                            NaN        NaN        NaN
# 14                                            NaN        NaN        NaN
# 15                                            NaN        NaN        NaN
# 16                                            NaN        NaN        NaN
# 17                                            NaN          1         10
# 18                                            NaN        NaN        NaN
# 19                                            NaN        NaN        NaN
# 20                                            NaN        NaN        NaN
# 21                                            NaN        NaN        NaN
# 22                                            NaN        NaN        NaN
# 23                                            NaN        NaN        NaN
# 24                                            NaN        NaN        NaN
# 25                                            NaN        NaN        NaN
#
#    Unnamed: 8 IN 11 SUNDRY VESSELS. Aggregate Tonnage 3,472. Unnamed: 10  \
# 0       Pkgs.                                        Pieces.     Peculs.
# 1         NaN                                            NaN         NaN
# 2         NaN                                            NaN         NaN
# 3         NaN                                            NaN         NaN
# 4         NaN                                            NaN          30
# 5         NaN                                            240         NaN
# 6         NaN                                            NaN         NaN
# 7         NaN                                            NaN         NaN
# 8         NaN                                            NaN         NaN
# 9         NaN                                            NaN         NaN
# 10        NaN                                            NaN          52
# 11        NaN                                            NaN         NaN
# 12        NaN                                            NaN          30
# 13        NaN                                            NaN         NaN
# 14        NaN                                            NaN         NaN
# 15        NaN                                            NaN         NaN
# 16        NaN                                            NaN          16
# 17        NaN                                            NaN          11
# 18        NaN                                            NaN         NaN
# 19        NaN                                            NaN         NaN
# 20        NaN                                            NaN         NaN
# 21        NaN                                            NaN          49
# 22        NaN                                            NaN         NaN
# 23        NaN                                            NaN         NaN
# 24        NaN                                            NaN           1
# 25        NaN                                            NaN         NaN
#
#    Unnamed: 11 Unnamed: 12 TOTAL. IN 23 VESSELS.\nAggregate Tonnage 7,637.  \
# 0         Cts.       Pkgs.                                         Pieces.
# 1          NaN         NaN                                             NaN
# 2          NaN         NaN                                             NaN
# 3          NaN         NaN                                             NaN
# 4           36         NaN                                             NaN
# 5          NaN         NaN                                             240
# 6          NaN         NaN                                             NaN
# 7          NaN         NaN                                             NaN
# 8          NaN         NaN                                             NaN
# 9          NaN         NaN                                           1,000
# 10          50         NaN                                             NaN
# 11         NaN         NaN                                           4,200
# 12          00         NaN                                             NaN
# 13          70         NaN                                             NaN
# 14         NaN         NaN                                               3
# 15         NaN         NaN                                             NaN
# 16          42         NaN                                             NaN
# 17          80         NaN                                             NaN
# 18         NaN         NaN                                             NaN
# 19         NaN         NaN                                             NaN
# 20         NaN         NaN                                             NaN
# 21          90         NaN                                             NaN
# 22         NaN         NaN                                             NaN
# 23         NaN         NaN                                              48
# 24          30         NaN                                             NaN
# 25         NaN         NaN                                             NaN
#
#    Unnamed: 14 Unnamed: 15 Unnamed: 16 ESTIMATED VALUE.  Unnamed: 18  \
# 0      Peculs.        Cts.       Pkgs.           Taels.          NaN
# 1           25          20         NaN            176.4          NaN
# 2           10          80         NaN            140.4          NaN
# 3           60          00         NaN            360.0          NaN
# 4           30          36         NaN            516.1          NaN
# 5          NaN         NaN         NaN          1,440.0          NaN
# 6            2          43         NaN             72.9          NaN
# 7           11          27         NaN             22.5          NaN
# 8          331          15         NaN          1,424.6          NaN
# 9          NaN         NaN         NaN          2,100.0          NaN
# 10         151          20         NaN          2,570.4          NaN
# 11         NaN         NaN         NaN            189.0          NaN
# 12          30          00         NaN             54.0          NaN
# 13           1          70         NaN            102.0          NaN
# 14         NaN         NaN         NaN             21.6          NaN
# 15         NaN          12         NaN             12.0          NaN
# 16          16          42         NaN            131.3          NaN
# 17          12          90         NaN            774.0          NaN
# 18          59          00         NaN         32,450.0          NaN
# 19           4          80         NaN          2,112.0          NaN
# 20           1          04         NaN            936.0          NaN
# 21          49          90         NaN            199.6          NaN
# 22         144          00         NaN            259.2          NaN
# 23         NaN         NaN         NaN             57.6          NaN
# 24           1          30         NaN             20.8          NaN
# 25         NaN         NaN         NaN         46,142.4          NaN
#
#     Unnamed: 19
# 0           NaN
# 1           NaN
# 2           NaN
# 3           NaN
# 4           NaN
# 5           NaN
# 6           NaN
# 7           NaN
# 8           NaN
# 9           NaN
# 10          NaN
# 11          NaN
# 12          NaN
# 13          NaN
# 14          NaN
# 15          NaN
# 16          NaN
# 17          NaN
# 18          NaN
# 19          NaN
# 20          NaN
# 21          NaN
# 22          NaN
# 23          NaN
# 24          NaN
# 25          NaN
# /Users/katherinemika/Desktop/curation/historic_datasets/returns_trade_ports/1866/csv/38485697_c.csv
#   DESCRIPTION. GREAT BRITAIN, direct. Unnamed: 2 Unnamed: 3  \
# 0          NaN                 Bales.    Peculs.       Cts.
# 1         Raw,                 24,370     19,315      03.25
# 2      Thrown,                    672        616         46
# 3       Japan,                    507        421      07.50
# 4      Coarse,                    126        118         44
# 5      Refuse,                    301        622         41
# 6     Cocoons,                    511        803         65
#
#   HONGKONG FOR GREAT BRITAIN, THE CONTINENT AND BOMBAY. Unnamed: 5 Unnamed: 6  \
# 0                                             Bales.       Peculs.       Cts.
# 1                                             36,930        28,641         61
# 2                                              2,410         2,196      12.25
# 3                                              4,370         3,376      72.25
# 4                                                 19            15         07
# 5                                                  6             6         63
# 6                                                  1             1         30
#
#   UNITED STATES. Unnamed: 8 Unnamed: 9 MANILA. Unnamed: 11 Unnamed: 12  \
# 0         Bales.    Peculs.       Cts.  Bales.     Peculs.        Cts.
# 1             55         43         96     119          95          19
# 2            NaN        NaN        NaN     NaN         NaN         NaN
# 3              9          5         46     NaN         NaN         NaN
# 4              2          4         78     NaN         NaN         NaN
# 5            NaN        NaN        NaN     NaN         NaN         NaN
# 6            NaN        NaN        NaN     NaN         NaN         NaN
#
#   FOOCHOW  AND AMOY. Unnamed: 14 Unnamed: 15  TOTAL. Unnamed: 17 Unnamed: 18
# 0             Bales.     Peculs.        Cts.  Bales.     Peculs.        Cts.
# 1                 52          41          84  61,526      48,137       63.25
# 2                NaN         NaN         NaN   3,082       2,812       58.50
# 3                NaN         NaN         NaN   4,860       3,803       25.25
# 4                NaN         NaN         NaN     147         138          29
# 5                NaN         NaN         NaN     306         629          04
# 6                NaN         NaN         NaN     512         804          95
# /Users/katherinemika/Desktop/curation/historic_datasets/returns_trade_ports/1866/csv/38485384.csv
#    DESCRIPTION OF GOODS. CLASSIFIER OF QUANTITY.  SHANGHAI.  Unnamed: 3  \
# 0                    NaN                     NaN  Quantity.         NaN
# 1               Carpets,                  Pieces         17         NaN
# 2                Cotton,                  Peculs        NaN         NaN
# 3          Fish, Cuttle,                       „        NaN         NaN
# 4                „ Salt,                       „          2        30.0
# 5              Foil Tin,                       „         19        20.0
# 6        Mussels, Dried,                       „        NaN         NaN
# 7       Oyesters, Dried,                       „         83        12.0
# 8          Peel, Orange,                       „         37        20.0
# 9      Silk Piece Goods,                       „          6         5.0
# 10          Skins, Fish,                       „         32         NaN
# 11         Sugar, White,                       „        NaN         NaN
# 12                  Tea,                       „        964        57.0
# 13    Tobacco, Prepared,                       „         34        50.0
# 14              Varnish,                       „          2        40.0
# 15            Vermilion,                       „          6        25.0
# 16                 Wool,                       „        NaN         NaN
# 17     Total Value Taels                     NaN        NaN         NaN
#
#    Unnamed: 4  KIUKIANG.  Unnamed: 6 Unnamed: 7 CHINKIANG.  Unnamed: 9  \
# 0      Value.  Quantity.         NaN     Value.  Quantity.         NaN
# 1          10        NaN         NaN        NaN        NaN         NaN
# 2         NaN          1        90.0         30        NaN         NaN
# 3         NaN        100         NaN        700        NaN         NaN
# 4          12        NaN         NaN        NaN        NaN         NaN
# 5         384        NaN         NaN        NaN        NaN         NaN
# 6         NaN         10        88.0         98        NaN         NaN
# 7         748        NaN         NaN        NaN        NaN         NaN
# 8         744        NaN         NaN        NaN        NaN         NaN
# 9       4,520          0        28.0        196        NaN         NaN
# 10        768        NaN         NaN        NaN        NaN         NaN
# 11        NaN        546        25.0      3,500        NaN         NaN
# 12     32,700        NaN         NaN        NaN        NaN         NaN
# 13        700        NaN         NaN        NaN        NaN         NaN
# 14         60        NaN         NaN        NaN         85        56.0
# 15        750        NaN         NaN        NaN        NaN         NaN
# 16        NaN          4        10.0         40        NaN         NaN
# 17     41,396        NaN         NaN      4,564        NaN         NaN
#
#    Unnamed: 10    NINGPO. Unnamed: 12     TOTAL.  Unnamed: 14 Unnamed: 15
# 0       Value.  Quantity.      Value.  Quantity.          NaN      Value.
# 1          NaN        NaN         NaN         17          NaN          10
# 2          NaN        NaN         NaN          1         90.0          30
# 3          NaN        NaN         NaN        100          NaN         700
# 4          NaN        NaN         NaN          2         30.0          12
# 5          NaN        NaN         NaN         19         20.0         384
# 6          NaN        NaN         NaN         10         88.0          98
# 7          NaN        NaN         NaN         83         12.0         748
# 8          NaN        NaN         NaN         37         20.0         744
# 9          NaN        NaN         NaN          6         33.0       4,716
# 10         NaN        NaN         NaN         32          NaN         768
# 11         NaN        NaN         NaN        546         25.0       3,500
# 12         NaN        NaN         NaN        964         57.0      32,700
# 13         NaN        NaN         NaN         34         50.0         700
# 14       3,420        NaN         NaN         87         96.0       3,480
# 15         NaN        NaN         NaN          6         25.0         750
# 16         NaN        NaN         NaN          4         10.0          40
# 17       3,420        NaN         NaN        NaN          NaN      49,380
# /Users/katherinemika/Desktop/curation/historic_datasets/returns_trade_ports/1866/csv/38484918.csv
#       DESCRIPTION OF GOODS. CLASSIFIER OF QUANTITY.  \
# 0                       NaN                     NaN
# 1              Beef, Dried,                 Peculs.
# 2      COTTON PIECE GOODS,—                     NaN
# 3          Shirtings White,                 Pieces.
# 4                   „ Dyed,                       „
# 5                   Chintz,                       „
# 6        Turkey Red Cloths,                       „
# 7            Cotton Thread,                 Peculs.
# 8                   „ Yarn,                       „
# 9              Cuttle Fish,                       „
# 10             Fish, Shell,                       „
# 11                 „ Skins,                       „
# 12  Hides, Buffalo and Cow,                       „
# 13             Metals, Tin,                       „
# 14                  OPIUM,—                     NaN
# 15                 Benares,                       „
# 16                   Patna,                       „
# 17                   Malwa,                       „
# 18                   Husks,                       „
# 19                   Paint,                       „
# 20              Tin Plates,                       „
# 21       Tobacco, Prepared,                       „
# 22               WOOLLENS,—                     NaN
# 23         Spanish Stripes,                 Pieces.
# 24        Camlets, English,                       „
# 25                Lastings,                       „
# 26            Wood, Garroo,                 Peculs.
# 27             TOTAL VALUE,                Dollars.
#
#    BRITISH POSSESSIONS IN THE STRAITS. Unnamed: 3 Unnamed: 4      JAVA.  \
# 0                            QUANTITY.        NaN     VALUE.  QUANTITY.
# 1
# 2                                  NaN        NaN        NaN        NaN
# 3
# 4
# 5
# 6
# 7
# 8
# 9
# 10                                   2         00         60          1
# 11
# 12
# 13
# 14                                 NaN        NaN        NaN        NaN
# 15                                   1         20        672
# 16
# 17
# 18
# 19
# 20
# 21
# 22                                 NaN        NaN        NaN        NaN
# 23
# 24
# 25
# 26
# 27                                 NaN        NaN        732        NaN
#
#    Unnamed: 6 Unnamed: 7    MANILA. Unnamed: 9 Unnamed: 10  HONGKONG.  \
# 0         NaN     VALUE.  QUANTITY.        NaN      VALUE.  QUANTITY.
# 1                                                                  19
# 2         NaN        NaN        NaN        NaN         NaN        NaN
# 3                                                                 416
# 4                                                                  50
# 5                                                                  98
# 6                                                                 550
# 7                                                                   1
# 8                                                                  48
# 9                                 5         00          50
# 10         00         26          2         00          22
# 11                                                                 15
# 12                                2         00          16
# 13                                         NaN                    414
# 14        NaN        NaN        NaN        NaN         NaN        NaN
# 15                                                                 13
# 16                                                                 18
# 17                                                                  2
# 18                                                                  3
# 19                                                                  9
# 20                                                                 37
# 21                                                                  2
# 22        NaN        NaN        NaN        NaN         NaN        NaN
# 23                                                                 14
# 24                                                                 55
# 25                                                                 20
# 26                                                                  2
# 27        NaN         26        NaN        NaN          88        NaN
#
#    Unnamed: 12 Unnamed: 13     TOTAL. Unnamed: 15 Unnamed: 16
# 0          NaN      VALUE.  QUANTITY.         NaN      VALUE.
# 1           00         190         19          00         190
# 2          NaN         NaN        NaN         NaN         NaN
# 3                    2,288        416                   2,288
# 4                      250         50                     250
# 5                      931         98                     931
# 6                    2,200        550                   2,200
# 7           60          96          1          60          96
# 8           00         384         48          00         384
# 9                                   5          00          50
# 10                                  5          00         108
# 11          00         150         15          00         150
# 12                                  2          00          16
# 13          00       1,242        414          00       1,242
# 14         NaN         NaN        NaN         NaN         NaN
# 15          20       7,392         14          40       8,064
# 16          00      10,386         18          00      10,386
# 17          00       1,320          2          00       1,320
# 18          00         372          3          00         372
# 19          00         190          9          00         190
# 20          00         370         37          00         370
# 21          00          40          2          00          40
# 22         NaN         NaN        NaN         NaN         NaN
# 23                     350         14                     350
# 24                   1,155         55                   1,155
# 25                     340         20                     340
# 26          00         150          2          00         150
# 27         NaN      29,796        NaN         NaN      30,642
# /Users/katherinemika/Desktop/curation/historic_datasets/returns_trade_ports/1866/csv/38485359_a.csv
#            FLAG. ENTERED INWARDS.  Unnamed: 2    Unnamed: 3 Unnamed: 4  \
# 0            NaN       WITH CARGO.        NaN  IN BALLAST.         NaN
# 1            NaN               No.      Tons.           No.      Tons.
# 2      British,                280    124,361            83     45,271
# 3     American,                 15      7,199             9      4,559
# 4       French,                  2        725           NaN        NaN
# 5      Russian,                  2      1,418           NaN        NaN
# 6     Prussian ,                 3        719           NaN        NaN
# 7      Hamburg,                 11      2,609             9      2,718
# 8       Bremen,                  6      2,221             2        632
# 9       Danish,                 23      4,795             6      1,058
# 10   Norwegian,                  1        183           NaN        NaN
# 11       Dutch,                  2        561           NaN        NaN
# ...
# 32                       NaN          2         00                       NaN
# 33                       NaN        280         16                       NaN
# 34                       NaN        NaN        NaN                       NaN
# 35                       NaN         23         04                       NaN
# 36                       NaN        NaN        NaN                       NaN
# 37                       NaN         25         61                       NaN
# 38                       NaN        NaN        NaN                       NaN
# 39                       NaN        NaN        NaN                    24,625
# 40                       NaN        NaN        NaN                       NaN
# 41                       NaN      4,261         10                       NaN
# 42                       NaN        NaN        NaN                       NaN
# 43                       NaN        NaN        NaN                       NaN
# 44                       NaN        NaN        NaN                       NaN
# 45                       NaN        241         11                       NaN
# 46                       NaN        227         45                       NaN
# 47                       NaN         30         82                       NaN
# 48                       NaN         94         82                       NaN
# 49                       NaN        103         74                       NaN
# 50                       NaN        NaN        NaN                       NaN
# 51                       NaN        NaN        NaN                       NaN
# 52                       NaN        438         21                       NaN
# 53                       NaN        NaN        NaN                       NaN
#
#    Unnamed: 8 Unnamed: 9        TOTAL IN 55 VESSELS Unnamed: 11 Unnamed: 12  \
# 0         NaN        NaN  Aggregate Tonnage 13,304.         NaN         NaN
# 1     Peculs.       Cts.                    Pieces.     Peculs.        Cts.
# 2         790         02                        NaN       1,821          69
# 3      11,124         00                        NaN      12,924          00
# 4           9         87                        NaN          21          21
# 5           6         50                        NaN           6          50
# 6       1,851         06                        NaN       3,421          87
# 7       2,837         48                        NaN       2,988          93
# 8         NaN        NaN                     11,400         NaN         NaN
# 9         NaN        NaN                      1,000         NaN         NaN
# 10        NaN        NaN                  2,258,800         NaN         NaN
# 11         59         00                        NaN         101          10
# 12          9         72                        NaN          91          83
# 13        NaN        NaN                      4,556         NaN         NaN
# 14         10         90                        NaN          24          30
# 15        159         75                        NaN         199          93
# 16         82         22                        NaN         189          68
# 17        NaN        NaN                        NaN           1          70
# 18        NaN        NaN                         88         NaN         NaN
# 19          5         92                        NaN           5          92
# 20         10         71                        NaN          11          86
# 21        860         70                        NaN         981          03
# 22         77         50                        NaN          77          50
# 23      1,746         43                        NaN       1,977          91
# 24      5,803         96                        NaN       7,774          21
# 25      2,393         47                        NaN       3,909          38
# 26         26         91                        NaN         102          97
# 27        709         00                        NaN         953          78
# 28         58         27                        NaN         112          27
# 29     65,392         02                        NaN      86,456          02
# 30         31         00                        NaN          31          00
# 31          9         12                        NaN           9          12
# 32         74         26                        NaN          76          26
# 33        145         14                        NaN         426          50
# 34        147         50                        NaN         147          50
# 35        679         05                        NaN         799          09
# 36        NaN        NaN                        240         NaN         NaN
# 37         70         69                        NaN         120          10
# 38        109         99                        NaN         130          56
# 39        NaN        NaN                     24,625         NaN         NaN
# 40        NaN         26                        NaN          23          26
# 41      2,951         62                        NaN       9,100          68
# 42         27         00                        NaN          27          00
# 43          2         80                        NaN          36          42
# 44        NaN        NaN                        NaN         233          22
# 45        689         50                        NaN       1,162          10
# 46        903         94                        NaN       2,469          08
# 47        102         54                        NaN         160          60
# 48        219         71                        NaN         388          77
# 49         23         87                        NaN         286          63
# 50          7         00                        NaN           7          00
# 51        NaN        NaN                        NaN         500          00
# 52        399         24                        NaN       1,804          19
# 53        NaN        NaN                        NaN         NaN         NaN
#
#    ESTIMATED VALUE.
# 0               NaN
# 1            Taels.
# 2            14,574
# 3            13,000
# 4               106
# 5               227
# 6            17,108
# 7             5,978
# 8             1,368
# 9                70
# 10            5,647
# 11            1,516
# 12            1,102
# 13           50,000
# 14            9,720
# 15              800
# 16            2,466
# 17               85
# 18            1,760
# 19              118
# 20              415
# 21            5,886
# 22              465
# 23            5,933
# 24           62,194
# 25           19,547
# 26            3,604
# 27            3,815
# 28              449
# 29          103,747
# 30              620
# 31              182
# 32              534
# 33           15,780
# 34              885
# 35            4,795
# 36              240
# 37           30,000
# 38            1,958
# 39            2,500
# 40              465
# 41           27,302
# 42              675
# 43            1,093
# 44            1,866
# 45           13,945
# 46            6,173
# 47              562
# 48            1,944
# 49           10,032
# 50              105
# 51            1,000
# 52            7,217
# 53          461,573
# /Users/katherinemika/Desktop/curation/historic_datasets/returns_trade_ports/1866/csv/38485976_1103-1104.csv
#     DESCIPTION OF GOODS.     IN 70 BRITISH VESSELS. Unnamed: 2 Unnamed: 3  \
# 0                    NaN  Aggregate Tonnage 27,535.        NaN        NaN
# 1                    NaN                    Pieces.    Peculs.       Cts.
# 2       Shirtings, Grey,                      2,958        NaN        NaN
# 3               „ White,                      3,723        NaN        NaN
# 4    T-Cloths, 24 yards,                      3,196        NaN        NaN
# ..                   ...                        ...        ...        ...
# 104           „ Kranjee,                        164        NaN        NaN
# 105               „ Red,                        NaN         14         00
# 106            „ Sandal,                        NaN          7         71
# 107             „ Sapan,                        NaN        389         20
# 108                  NaN                        NaN        NaN        NaN
#
#        IN 6 AMERICAN VESSELS. Unnamed: 5 Unnamed: 6     IN 28 SUNDRY VESSELS.  \
# 0    Aggregate Tonnage 2,807.        NaN        NaN  Aggregate Tonnage 9,725.
# 1                     Pieces.    Peculs.       Cts.                   Pieces.
# 2                         NaN        NaN        NaN                       420
# 3                         NaN        NaN        NaN                       202
# 4                         NaN        NaN        NaN                       NaN
# ..                        ...        ...        ...                       ...
# 104                       NaN        NaN        NaN                       201
# 105                       NaN        NaN        NaN                       NaN
# 106                       NaN         40         47                       NaN
# 107                       NaN        NaN        NaN                       NaN
# 108                       NaN        NaN        NaN                       NaN
#
#     Unnamed: 8 Unnamed: 9 IN WEST COAST BOATS. Unnamed: 11 Unnamed: 12  \
# 0          NaN        NaN                  NaN         NaN         NaN
# 1      Peculs.       Cts.              Pieces.     Peculs.        Cts.
# 2          NaN        NaN               11,409         NaN         NaN
# 3          NaN        NaN                1,145         NaN         NaN
# 4          NaN        NaN               20,340         NaN         NaN
# ..         ...        ...                  ...         ...         ...
# 104        NaN        NaN                  NaN         NaN         NaN
# 105        NaN        NaN                  NaN         NaN         NaN
# 106        249         77                  NaN         NaN         NaN
# 107        843         35                  NaN         161          65
# 108        NaN        NaN                  NaN         NaN         NaN
#
#          TOTAL IN 104 VESSELS. Unnamed: 14 Unnamed: 15 ESTIMATED VALUE.
# 0    Aggregate Tonnage 40,067.         NaN         NaN              NaN
# 1                      Pieces.     Peculs.        Cts.         Dollars.
# 2                       14,787         NaN         NaN           44,361
# 3                        5,070         NaN         NaN           15,210
# 4                       23,536         NaN         NaN           41,188
# ..                         ...         ...         ...              ...
# 104                        365         NaN         NaN            7,300
# 105                        NaN          14          00               28
# 106                        NaN         297          95            2,979
# 107                        NaN       1,494          20            2,988
# 108                        NaN         NaN         NaN       $2,524,223
#
# [109 rows x 17 columns]
# /Users/katherinemika/Desktop/curation/historic_datasets/returns_trade_ports/1866/csv/38485485_a.csv
#      No.           FLAG. TONNAGE. IMPORT. Unnamed: 4 Unnamed: 5 Unnamed: 6  \
# 0    NaN             NaN      NaN  Taels.         m.         c.         c.
# 1   53.0        BRITISH,   17,770     914          8          7          3
# 2   16.0       AMERICAN,    6,112     163          3          4          1
# 3  182.0         SUNDRY,   49,910   2,624          4          7          7
# 4    1.0        SIAMESE,      300      29          6          0          5
# 5  252.0  Vessels, Tons,   74,902   3,732          2          9          6
# 6    NaN             NaN      NaN     NaN        NaN        NaN        NaN
# 7    NaN             NaN      NaN     NaN        NaN        NaN        NaN
# 8    NaN             NaN      NaN     NaN        NaN        NaN        NaN
#
#   EXPORT. Unnamed: 8 Unnamed: 9  ... Unnamed: 21 Unnamed: 22 TONNAGE DUES.  \
# 0  Taels.         m.         c.  ...          c.          c.        Taels.
# 1  18,446          3          3  ...           1           6           976
# 2   3,855          1          6  ...           2           5           353
# 3  57,520          3          9  ...           8           1         3,892
# 4     287          9          0  ...         NaN         NaN           NaN
# 5  80,109          7          9  ...           2           2         5,222
# 6     NaN        NaN        NaN  ...         NaN         NaN           NaN
# 7     NaN        NaN        NaN  ...         NaN         NaN           NaN
# 8     NaN        NaN        NaN  ...         NaN         NaN           NaN
#
#   Unnamed: 24 Unnamed: 25 Unnamed: 26   TOTAL. Unnamed: 28 Unnamed: 29  \
# 0          m.          c.          c.   Taels.          m.          c.
# 1           0           0           0   23,110           4           2
# 2           2           0           0    5,011           7           3
# 3           8           0           0   76,103           8           5
# 4         NaN         NaN         NaN      503           5           0
# 5           0           0           0  104,729           5           1
# 6         NaN         NaN         NaN      NaN         NaN         NaN
# 7         NaN         NaN         NaN      NaN         NaN         NaN
# 8         NaN         NaN         NaN      NaN         NaN         NaN
#
#   Unnamed: 30
# 0          c.
# 1           3
# 2           0
# 3           2
# 4           6
# 5           1
# 6         NaN
# 7         NaN
# 8         NaN
#
# [9 rows x 31 columns]
# /Users/katherinemika/Desktop/curation/historic_datasets/returns_trade_ports/1866/csv/38485821.csv
#   The quantity exported Direct to Great Britain was  Peculs  \
# 0               exported to Foreign Countries  Taels
# 1  The total value of Exports to Foreign Countrie...
#
#   333,675.57 making the total value of Cotton,
# 0                                    6,570,111
# 1                               = £ 10,103,566
# /Users/katherinemika/Desktop/curation/historic_datasets/returns_trade_ports/1866/csv/38485373_b.csv
#                                           Unnamed: 0 SHANGHAI. Unnamed: 2  \
# 0                                                NaN       No.      Tons.
# 1                                          British,         13      2,885
# 2                                         American,          3      1,515
# 3  Sundry,(1  Danish 216 Tons and the balance Fre...         1        216
# 4                                            TOTAL,         17      4,616
#
#   SHANGHAI AND LONDON. Unnamed: 4 SHANGHAI AND NINGPO. Unnamed: 6  \
# 0                  No.      Tons.                  No.      Tons.
# 1                    6      3,868                    2        367
# 2                  NaN        NaN                    1        369
# 3                  NaN        NaN                  NaN        NaN
# 4                    6      3,868                    3        736
#
#   KIUKIANG, SHANGHAI AND LONDON. Unnamed: 8 KIUKIANG. Unnamed: 10 CHINKIANG.  \
# 0                            No.      Tons.       No.       Tons.        No.
# 1                              2      2,331       NaN         NaN          1
# 2                            NaN        NaN         1         117        NaN
# 3                            NaN        NaN       NaN         NaN        NaN
# 4                              2      2,331         1         117          1
#
#   Unnamed: 12 NINGPO. Unnamed: 14 TOTAL. Unnamed: 16
# 0       Tons.     No.       Tons.    No.       Tons.
# 1         268       9         499     33      10,218
# 2         NaN      20       1,191     25       3,192
# 3         NaN       3         374      4         590
# 4         268      32       2,064     62      14,000

# %%
df = pd.read_csv("/Users/katherinemika/Desktop/curation/historic_datasets/trade_statistics_treaty_ports/1873/csv/44319905.csv")
df
# Out:
#                  Unnamed: 0           1863.           1864.           1865.  \
# 0                       NaN  Hk. Tts. m.c.c  Hk. Tts. m.c.c  Hk. Tts. m.c.c
# 1                 British,      1,817.9.2.3    24,333.7.2.1    22,135.5.3.8
# 2                American,              NaN             NaN       693.0.5.6
# 3                  French,              NaN       694.0.6.6     2,168.6.3.1
# 4   Swedish and Norwegian,              NaN     1,728.1.4.3     2,135.6.8.1
# 5                 Russian,              NaN             NaN             NaN
# 6                  German,      6,818.6.3.0    11,523.7.8.4     21,367.0.54
# 7                  Danish,      7,573.9.4.0     9,571.6.7.9     5,704.0.2.9
# 8                   Dutch,              NaN             NaN       308.3.4.5
# 9                 Spanish,              NaN             NaN        77.2.0.0
# 10                Belgian,              NaN             NaN             NaN
# 11                Italian,              NaN             NaN             NaN
# 12               Austrian,              NaN             NaN             NaN
# 13      Non-Treaty Powers,              NaN             NaN       339.0.9.5
# 14           Transit Dues,              NaN             NaN             NaN
# 15                  TOTAL,     16,210.4.8.3    47,351.3.9.3    54,988.6.2.8
#
#              1866.           1867.           1868.           1869.  \
# 0   Hk. Tts. m.c.c  Hk. Tts. m.c.c  Hk. Tts. m.c.c  Hk. Tts. m.c.c
# 1     11,724.2.3.3    23,545.4.9.5    16,915.4.3.8    17,377.7.3.2
# 2        811.9.8.1       131.5.5.6     1,423.1.9.7             NaN
# 3         689.5.44     3,293.5.6.3     3,918.0.7.1     3,152.8.1.4
# 4        979.1.4.2             NaN        881.42.7             NaN
# 5              NaN             NaN             NaN     2,052.0.0.0
# 6     34,574.9.3.9    40,324.5.8.5    27,558.1.3.3    43,008.7.4.5
# 7        388.9.4.9     1,175.9.8.9             NaN     5,336.4.2.2
# 8      2,166.4.4.7             NaN       790.6.9.0     1,697.5.9.4
# 9              NaN             NaN             NaN             NaN
# 10             NaN             NaN             NaN             NaN
# 11             NaN             NaN             NaN             NaN
# 12             NaN             NaN             NaN             NaN
# 13        29.0.4.5             NaN             NaN        75.6.3.6
# 14             NaN             NaN             NaN             NaN
# 15    51,364.2.8.0    68,471,1.8.8    51,486.9.5.6     72,700.9.43
#
#              1870.           1871.           1872.
# 0   Hk. Tts. m.c.c  Hk. Tts. m.c.c  Hk. Tts. m.c.c
# 1     30,045.0.5.4    52,714.5.7.8    58,395.8.6.8
# 2      3,372.5.0.0     3,686.6.1.5     3,712.9.3.2
# 3      3,937.7.8.0     6,972.3.8.4     3,311.8.8.2
# 4      5,953.6.0.8     7,995.9.2.0     3,766.8.2.1
# 5              NaN       662.6.7.6             NaN
# 6     49,000.0.6.1    21,682.1.9.2    33,014.9.3.2
# 7     13,045.3.9.0     12,889.0.90     1,525.4.6.4
# 8      6,077.4.3.8    10,203.4.0.6     5,412.7.5.7
# 9              NaN             NaN             NaN
# 10             NaN             NaN             NaN
# 11             NaN             NaN             NaN
# 12             NaN             NaN             NaN
# 13       350.1.9.0       491.0.1.2     1,553.2.3.5
# 14       743.4.2.0             NaN             NaN
# 15   112,525.4.4.1   117,297.8.7.3   110,694.8.9.1
